# %%
# Title: Simulated Falls and Daily Living Activities Dataset (https://www.mdpi.com/1424-8220/14/6/10691)

'''
- Cơ sở dữ liệu bao gồm dữ liệu của 10 nam và 8 nữ tình nguyện viên (Ví dụ: 101)
- Thư mục tình nguyện viện chứa các bản ghi hoạt động tương ứng với tên lớp hành động và tên tình nguyện viên (Ví dụ: 801-Yurume Ileri)
- Mỗi hoạt động chứa ít nhất 5 thử nghiệm, một số hoạt động chứa 6 thử nghiệm (Ví dụ: Test_1)
- Mỗi bài kiểm tra chứa 6 dữ liệu của cảm biến (Ví dụ: 340535)
Ví dụ về đường dẫn đến tệp dữ liệu: "C:/Users/vieth/Downloads/Dataset Simulated Falls and Daily Living Activities/101/Testler Export/801-Yurume Ileri/Test_1/340535.txt"
'''

'''
Information About Data Formation:
- Tên thư mục 1XX: Tình nguyện viên nam
- Tên thư mục 2XX: Tình nguyện viên nữ
- Tên thư mục 8XX: Các hoạt động sinh hoạt hàng ngày (Activities of Daily Living)
- Tên thư mục 9XX: Các hành động ngã (Fall Actions)
'''

''''
16 class of Non-Fall Actions (ADLs)
 1. 801 walking-fw                  - Đi bộ về phía trước
 2. 802 walking-bw                  - Đi bộ lùi lại
 3. 803 jogging                     - Chạy bộ nhẹ
 4. 804 squatting-down              - Ngồi xổm xuống, ngồi xổm rồi đứng lên
 5. 805 bending                     - Cúi người, cúi khoảng 90 độ
 6. 806 bending-pick-up             - Cúi xuống để nhặt vật gì đó trên sàn
 7. 807 limp                        - Đi bộ với dáng đi khập khiễng
 8. 808 stumble                     - Vấp ngã rồi phục hồi
 9. 809 trip-over                   - Cúi khi đi bộ rồi tiếp tục đi
10. 810 coughing-sneezing           - Ho hoặc hắt hơi
11. 811 sit-chair from vertical     - Ngồi xuống ghế từ tư thế thẳng đứng với một gia tốc nhất định trên ghế (bề mặt cứng)              - not considered (811)
12. 812 sit-sofa from vertical      - Ngồi xuống sofa từ tư thế thẳng đứng với một gia tốc nhất định trên sofa (bề mặt mềm)             - not considered (812)
13. 813 sit-air from vertical       - Ngồi xuống không khí từ tư thế thẳng đứng, sử dụng cơ bắp chân
14. 814 sit-bed from vertical       - Ngồi xuống giường từ tư thế thẳng đứng với một gia tốc nhất định trên giường (bề mặt mềm)         - not considered (814)
15. 815 lying-bed                   - Nằm trên giường từ tư thế thẳng đứng                                                              - not considered (815)
16. 816 rising-bed                  - Từ tư thế nằm chuyển sang ngồi                                                                    - not considered (816)
'''

'''
20 class of FALL ACTIONS:
 1. 901 front-lying                 - Ngã về phía trước, từ tư thế thẳng đứng ngã về phía trước xuống sàn
 2. 902 front-protecting-lying      - Ngã về phía trước, từ tư thế thẳng đứng ngã về phía trước xuống sàn với sự bảo vệ bằng tay
 3. 903 front-knees                 - Ngã về phía trước, từ tư thế thẳng đứng ngã xuống đầu gối                                         - not considered (903)
 4. 904 front-knees-lying           - Ngã về phía trước, từ tư thế thẳng đứng ngã xuống đầu gối rồi nằm xuống sàn
 5. 905 front-quick-recovery        - Ngã về phía trước, từ tư thế thẳng đứng ngã xuống sàn và phục hồi nhanh chóng                     - non-fall (fall recovery) (905)
 6. 906 front-slow-recovery         - Ngã về phía trước, từ tư thế thẳng đứng ngã xuống sàn và phục hồi chậm
 7. 907 front-right                 - Ngã về phía trước, từ tư thế thẳng đứng ngã xuống sàn, kết thúc ở tư thế nằm nghiêng bên phải
 8. 908 front-left                  - Ngã về phía trước, từ tư thế thẳng đứng ngã xuống sàn, kết thúc ở tư thế nằm nghiêng bên trái
 9. 909 back-sitting                - Ngã về phía sau, từ tư thế thẳng đứng ngã xuống sàn, kết thúc ngồi                                - not considered (909)
10. 910 back-lying                  - Ngã về phía sau, từ tư thế thẳng đứng ngã xuống sàn, kết thúc nằm
11. 911 back-right                  - Ngã về phía sau, từ tư thế thẳng đứng ngã xuống sàn, kết thúc nằm nghiêng bên phải
12. 912 back-left                   - Ngã về phía sau, từ tư thế thẳng đứng ngã xuống sàn, kết thúc nằm nghiêng bên trái
13. 913 right-sideway               - Ngã về phía bên phải, từ tư thế thẳng đứng ngã xuống sàn, kết thúc nằm
14. 914 right-recovery              - Ngã về phía bên phải, từ tư thế thẳng đứng ngã xuống sàn và phục hồi sau đó                       - non-fall (fall recovery) (914)
15. 915 left-sideway                - Ngã về phía bên trái, từ tư thế thẳng đứng ngã xuống sàn, kết thúc nằm
16. 916 left-recovery               - Ngã về phía bên trái, từ tư thế thẳng đứng ngã xuống sàn và phục hồi sau đó                       - non-fall (fall recovery) (916)
17. 917 rolling-out-bed             - Ngã ra khỏi giường, từ tư thế nằm, lăn ra khỏi giường và ngã xuống sàn                            - not considered (917)
18. 918 podium                      - Ngã từ bục, từ tư thế đứng thẳng trên bục ngã xuống sàn
19. 919 syncope                     - Ngã do ngất xỉu, từ tư thế đứng ngã xuống sàn theo quỹ đạo thẳng đứng
20. 920 syncope-wall                - Ngã do ngất xỉu, từ tư thế đứng ngã xuống chậm, trượt trên một bức tường
'''

'''
Each sensor has individual code
- 340506: Cảm biến đầu
- 340527: Cảm biến ngực
- 340535: Cảm biến eo
- 340537: Cảm biến cổ tay phải
- 340539: Cảm biến đùi phải
- 340540: Cảm biến mắt cá chân phải
'''
# Out:
# '\nEach sensor has individual code\n- 340506: Cảm biến đầu\n- 340527: Cảm biến ngực\n- 340535: Cảm biến eo\n- 340537: Cảm biến cổ tay phải\n- 340539: Cảm biến đùi phải\n- 340540: Cảm biến mắt cá chân phải\n'

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import confusion_matrix, roc_auc_score, f1_score
import time
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from scipy import stats, signal
import matplotlib.cm as cm
from matplotlib.colors import ListedColormap, BoundaryNorm
import matplotlib.patches as mpatches
from scipy.signal import find_peaks, savgol_filter
from scipy.stats import entropy, skew, kurtosis
from scipy.signal import welch
from numpy import cov
import matplotlib.colors as mcolors
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.ar_model import AutoReg
from IPython.core.interactiveshell import InteractiveShell
# from plotly.graph_objs import go
from plotly.subplots import make_subplots
import plotly.io as pio
import plotly.offline as pyo
import json
import warnings
import math
import scipy as sp
import scipy.fftpack
import os
# Lấy thư mục làm việc hiện tại trong Jupyter Notebook
current_file_directory = os.getcwd()

# Chuyển thư mục làm việc
os.chdir(current_file_directory)
import tkinter as tk
from tkinter import messagebox
import pickle
import easygui
import joblib
import sys
import xgboost as xgb
import lightgbm as lgb

def calculate_metrics(conf_matrix, class_labels):
    # Tính toán TP, FP, FN, TN
    TP = np.diag(conf_matrix)
    FP = np.sum(conf_matrix, axis=0) - TP
    FN = np.sum(conf_matrix, axis=1) - TP
    TN = np.sum(conf_matrix) - (TP + FP + FN)

    # Tính Accuracy, Sensitivity, Specificity cho từng lớp
    accuracy = (TP + TN) / (TP + FP + TN + FN)
    sensitivity = TP / (TP + FN)
    specificity = TN / (TN + FP)
    precision = TP / (TP + FP)
    f1 = 2 * (precision * sensitivity) / (precision + sensitivity)

    metrics = []
    for i in range(len(conf_matrix)):
        metrics.append({
            'Activity': class_labels[i],
            'Acc': round(accuracy[i] * 100, 1),
            'Sen': round(sensitivity[i] * 100, 1),
            'Spe': round(specificity[i] * 100, 1),
            'Pre': round(precision[i] * 100, 1),
            'F1': round(f1[i] * 100, 1)
        })

    # Tạo y_true và y_pred từ ma trận nhầm lẫn để tính f1_micro
    y_true_all = []
    y_pred_all = []
    for i in range(len(conf_matrix)):
        for j in range(len(conf_matrix)):
            count = conf_matrix[i, j]
            y_true_all += [i] * count
            y_pred_all += [j] * count

    f1_micro = f1_score(y_true_all, y_pred_all, average='micro', zero_division=0)

    # Tính trung bình các chỉ số (bỏ qua NaN)
    avg_accuracy = np.nanmean(accuracy)
    avg_sensitivity = np.nanmean(sensitivity)
    avg_specificity = np.nanmean(specificity)
    avg_precision = np.nanmean(precision)
    return avg_accuracy, avg_sensitivity, avg_specificity, avg_precision, f1_micro

def model_size_in_bytes(model):
    return len(pickle.dumps(model))

def calculate_auc_multiclass(model, test_features, label_test):
    try:
        predicted_probs = model.predict_proba(test_features)
        return roc_auc_score(label_test, predicted_probs, multi_class='ovr')
    except:
        return None
    
def extract_peak_segment_with_noise_padding(df,left_,right_):
    acc_mag = np.sqrt(df['Acc_X']**2 + df['Acc_Y']**2 + df['Acc_Z']**2)
    peak_idx = acc_mag.idxmax()

    left_size = left_
    right_size = right_

    start_idx = peak_idx - left_size
    end_idx = peak_idx + right_size + 1

    left_part = df.iloc[max(0, start_idx):peak_idx]
    peak_row = df.iloc[[peak_idx]]
    right_part = df.iloc[peak_idx + 1:min(len(df), end_idx)]

    def generate_noisy_samples(ref_df, num_samples):
        mean = ref_df.mean(numeric_only=True)
        numeric_cols = mean.index
        noise = np.random.uniform(-0.05, 0.05, size=(num_samples, len(numeric_cols)))
        samples = mean.values + noise
        gen_df = pd.DataFrame(samples, columns=numeric_cols)

        # Xử lý cột không phải số (vd: timestamp)
        for col in df.columns:
            if col not in numeric_cols:
                gen_df[col] = np.nan
        return gen_df[df.columns]

    # Padding trái
    if len(left_part) < left_size:
        pad_count = left_size - len(left_part)
        pad_data = generate_noisy_samples(df.iloc[:20], pad_count)
        left_part = pd.concat([pad_data, left_part], ignore_index=True)

    # Padding phải
    if len(right_part) < right_size:
        pad_count = right_size - len(right_part)
        pad_data = generate_noisy_samples(df.iloc[-20:], pad_count)
        right_part = pd.concat([right_part, pad_data], ignore_index=True)

    segment = pd.concat([left_part, peak_row, right_part], ignore_index=True)

    return segment
def feature_selection_with_rf(train_features, test_features, label_train, label_test, feature_names, threshold):
    import matplotlib.pyplot as plt
    import numpy as np
    from sklearn.ensemble import RandomForestClassifier

    remaining_features = feature_names.copy()
    X_train, X_test = np.array(train_features), np.array(test_features)
    
    removed_features_all = []  # Danh sách chứa các đặc trưng bị loại bỏ và giá trị quan trọng của chúng

    while len(remaining_features) > 1:
        # Huấn luyện Random Forest
        clf = RandomForestClassifier(n_estimators=14,max_depth=18,max_features='sqrt',bootstrap=False, random_state=20)
        clf.fit(X_train, label_train)

        # Tầm quan trọng của đặc trưng
        importances = clf.feature_importances_

        # Sắp xếp theo thứ tự giảm dần (cao -> thấp)
        sorted_idx = np.argsort(importances)[::-1]
        sorted_importances = importances[sorted_idx]
        sorted_features = [remaining_features[i] for i in sorted_idx]

        # Lọc các đặc trưng có độ quan trọng >= threshold
        important_indices = sorted_idx[sorted_importances >= threshold]
        removed_indices = sorted_idx[sorted_importances < threshold]

        # Nếu không còn đặc trưng nào dưới ngưỡng, thoát vòng lặp
        if len(removed_indices) == 0:
            # print("No features removed (all importance >= threshold).")
            break

        # Lưu các đặc trưng bị loại bỏ và giá trị quan trọng của chúng
        removed_features = [(remaining_features[i], importances[i]) for i in removed_indices]
        removed_features_all.extend(removed_features)
        # print(f"Removing features: {', '.join([f'{f[0]} ({f[1]:.4f})' for f in removed_features])}")

        # Cập nhật tập dữ liệu và danh sách đặc trưng còn lại
        remaining_features = [remaining_features[i] for i in important_indices]
        X_train = X_train[:, important_indices]
        X_test = X_test[:, important_indices]

    # Chuẩn bị dữ liệu cho biểu đồ
    final_importances = clf.feature_importances_
    sorted_idx = np.argsort(final_importances)[::-1]
    remaining_features_sorted = [remaining_features[i] for i in sorted_idx]
    remaining_importances_sorted = final_importances[sorted_idx]

    removed_features_sorted = sorted(removed_features_all, key=lambda x: x[1], reverse=True)
    removed_feature_names = [f[0] for f in removed_features_sorted]
    removed_importances = [f[1] for f in removed_features_sorted]

    all_features = remaining_features_sorted + removed_feature_names
    all_importances = list(remaining_importances_sorted) + list(removed_importances)
    all_colors = ['skyblue'] * len(remaining_features_sorted) + ['red'] * len(removed_feature_names)

    # Tính độ lệch chuẩn của tất cả các giá trị quan trọng
    all_importances_std = np.std(all_importances)
    print(f"\nStandard deviation of importance scores (including removed and remaining features): {all_importances_std:.4f}")
    print(f"\n Mean of importance scores (including removed and remaining features): {np.mean(all_importances):.4f}")
    # Vẽ biểu đồ gộp
    plt.figure(figsize=(8, max(6, len(all_features) * 0.15)))
    plt.barh(all_features, all_importances, color=all_colors)
    plt.xlabel("Importance Score")
    plt.ylabel("Features")
    plt.gca().invert_yaxis()  # Đảm bảo các đặc trưng quan trọng nhất ở trên cùng
    # Thêm chú thích
    important_patch = plt.Line2D([0], [0], color='skyblue', lw=4, label='Important Features')
    less_important_patch = plt.Line2D([0], [0], color='red', lw=4, label='Less Important Features')
    plt.legend(handles=[important_patch, less_important_patch], loc='lower right')

    plt.tight_layout()
    plt.show()

    # print("\nFinal remaining features:")
    # for feature, importance in zip(remaining_features_sorted, remaining_importances_sorted):
    #     print(f"{feature}")

    # print("\nRemoved features (sorted by importance):")
    # for feature, importance in removed_features_sorted:
    #     print(f"{feature}: {importance:.4f}")

    return X_train, X_test, remaining_features

# Hàm tính toán Accuracy, Sensitivity, Specificity và F1-Score cho mỗi ma trận nhầm lẫn

def filter_acc_axes(data, fs=25, std_threshold=0.2):
    """
    Lọc dữ liệu gia tốc 3 trục 'Acc_X', 'Acc_Y', 'Acc_Z' bằng cách loại bỏ các phân đoạn 1 giây 
    có độ lệch chuẩn của S_a nhỏ hơn ngưỡng (0.2).

    Tham số:
        - data: DataFrame chứa các cột 'Acc_X', 'Acc_Y', 'Acc_Z'.
        - fs: Tần số lấy mẫu (Hz), mặc định 25 Hz.
        - std_threshold: Ngưỡng độ lệch chuẩn, mặc định 0.2.

    Trả về:
        - filtered_data: DataFrame chứa tín hiệu 3 trục đã được lọc.
        - indices: Các chỉ số được giữ lại.
    """
    # Trích xuất các trục gia tốc từ DataFrame
    a_x = data['Acc_X'].to_numpy()
    a_y = data['Acc_Y'].to_numpy()
    a_z = data['Acc_Z'].to_numpy()

    # Tính S_a (độ lệch tổng hợp)
    S_a = np.sqrt((a_x - np.mean(a_x))**2 + (a_y - np.mean(a_y))**2 + (a_z - np.mean(a_z))**2)

    # Kích thước cửa sổ (1 giây tương ứng với fs mẫu)
    window_size = fs
    num_segments = len(S_a) // window_size

    # Lọc tín hiệu 3 trục
    filtered_indices = []  # Lưu các chỉ số giữ lại
    for i in range(num_segments):
        start_idx = i * window_size
        end_idx = start_idx + window_size
        segment = S_a[start_idx:end_idx]

        # Kiểm tra độ lệch chuẩn của phân đoạn
        if np.std(segment) >= std_threshold:
            filtered_indices.extend(range(start_idx, end_idx))

    # Tạo DataFrame mới chứa các tín hiệu đã được giữ lại
    filtered_data = data.iloc[filtered_indices].reset_index(drop=True)
    return filtered_data, S_a

def handle_nan_rows(data):
    """
    Quét DataFrame tìm các giá trị NaN:
    - Nếu hàng xuất hiện NaN, thay thế bằng trung bình cộng của hàng liền kề trước và sau (tính trên từng cột chứa NaN).
    - Nếu hàng đầu tiên hoặc hàng cuối cùng chứa NaN, xóa hàng đó đi.
    - Nếu có 2 hàng liên tiếp chứa NaN ở cùng một cột, xóa cả hai hàng đó.
    - Nếu các hàng chứa NaN ở các cột khác nhau, xử lý từng cột riêng biệt.
    - Hiển thị thông tin các hàng có 2 hàng liên tiếp chứa NaN ở cùng một cột.

    Parameters:
    - data (pd.DataFrame): DataFrame cần xử lý.

    Returns:
    - pd.DataFrame: DataFrame đã xử lý.
    """
    error_=0
    # Tạo bản sao của DataFrame để không làm thay đổi dữ liệu gốc
    data = data.copy()

    # Lặp lại quá trình xử lý cho đến khi không còn NaN
    while data.isna().any().any():
        indexes_to_drop = []  # Lưu danh sách các hàng cần xóa

        for index in range(len(data)):
            if data.iloc[index].isna().any():  # Kiểm tra hàng có giá trị NaN
                if index == 0 or index == len(data) - 1:  # Nếu là hàng đầu tiên hoặc hàng cuối cùng
                    indexes_to_drop.append(index)
                elif index < len(data) - 1 and data.iloc[index].isna().any() and data.iloc[index + 1].isna().any():
                    # Nếu có 2 hàng liên tiếp chứa NaN ở cùng cột
                    nan_columns = data.iloc[index].isna() & data.iloc[index + 1].isna()
                    if nan_columns.any():
                        print(f"Hai hàng liên tiếp chứa NaN ở cùng cột: hàng {index} và hàng {index + 1}, cột: {list(data.columns[nan_columns])}")
                        indexes_to_drop.extend([index, index + 1])
                        error_=1
                    else:
                        # Xử lý bình thường nếu NaN ở các cột khác nhau
                        for col in data.columns:
                            if pd.isna(data.iloc[index][col]):
                                data.at[index, col] = (data.iloc[index - 1][col] + data.iloc[index + 1][col]) / 2
                else:
                    # Xử lý bình thường (từng cột riêng biệt)
                    for col in data.columns:
                        if pd.isna(data.iloc[index][col]):
                            data.at[index, col] = (data.iloc[index - 1][col] + data.iloc[index + 1][col]) / 2

        data.drop(index=indexes_to_drop, inplace=True)

        # Reset lại chỉ số sau khi xóa hàng
        data.reset_index(drop=True, inplace=True)

    return data,error_

# Định nghĩa các cột trong dữ liệu
columns = [
    'Counter', 'Temperature',
    'VelInc_X', 'VelInc_Y', 'VelInc_Z',
    'OriInc_w', 'OriInc_x', 'OriInc_y', 'OriInc_z',
    'Acc_X', 'Acc_Y', 'Acc_Z',
    'Gyr_X', 'Gyr_Y', 'Gyr_Z',
    'Mag_X', 'Mag_Y', 'Mag_Z', 'Pressure',
    'Roll', 'Pitch', 'Yaw',
    'RSSI'
]


def featuresFromBuffer(at):
    feat = np.zeros(48)   
    ax = np.array(at['Acc_X'], dtype=np.float64)
    ay = np.array(at['Acc_Y'], dtype=np.float64)
    az = np.array(at['Acc_Z'], dtype=np.float64)
    mag = np.sqrt(ax**2+ay**2+az**2)-1
    # Mean
    mean_acc = [np.mean(i) for i in [ax, ay, az]]
    feat[0:3] = mean_acc

    # Energy
    energy_acc = [np.sqrt(np.mean(i**2)) for i in [ax, ay, az]]
    feat[3:6] = energy_acc

    # Standard Deviation (std)
    std_acc = [np.std(i) for i in [ax, ay, az]]
    feat[6:9] = std_acc

    # Maximum
    max_ = [np.max(i) for i in [ax, ay, az]]
    feat[9:12] = max_

    # Range
    Range_acc = [np.amax(i) - np.amin(i) for i in [ax, ay, az]]
    feat[12:15] = Range_acc

    # Mean Absolute Deviation
    mad_acc = [np.mean(np.abs(i - np.mean(i))) for i in [ax, ay, az]]
    feat[15:18] = mad_acc

    # Skewness
    skewness_acc = [skew(i) for i in [ax, ay, az]]
    feat[18:21] = skewness_acc

    # Kurtosis
    kurtosis_acc = [kurtosis(i) for i in [ax, ay, az]]
    feat[21:24] = kurtosis_acc

    # Interquartile Range
    iqr_val = [np.percentile(i, 75) - np.percentile(i, 25) for i in [ax, ay, az]]
    feat[24:27] = iqr_val

    # Signal Magnitude Area (SMA)
    sma_acc = [np.sum(np.abs(i)) for i in [ax, ay, az]]
    feat[27:30] = sma_acc

    # Simple Square Integral
    ssi_acc = [np.sum(i**2) for i in [ax, ay, az]]
    feat[30:33] = ssi_acc

    # Median Absolute Deviation
    median_mad_acc = [np.median(np.abs(i - np.median(i))) for i in [ax, ay, az]]
    feat[33:36] = median_mad_acc
    
    # Hjorth Mobility
    hjorth_mobility_acc = [np.sqrt(np.var(np.diff(i)) / np.var(i)) for i in [ax, ay, az]]
    feat[36:39] = hjorth_mobility_acc  # Vị trí lưu Hjorth Mobility

    # Hjorth Complexity
    hjorth_complexity_acc = [
        (np.sqrt(np.var(np.diff(np.diff(i))) / np.var(np.diff(i))) /
        np.sqrt(np.var(np.diff(i)) / np.var(i)))
        for i in [ax, ay, az]
    ]
    feat[39:42] = hjorth_complexity_acc  # Vị trí lưu Hjorth Complexity
    
    #  (lag=1)
    autocorr_acc = [acf(i, nlags=1)[1] for i in [ax, ay, az]]
    feat[42:45] = autocorr_acc  # Vị trí lưu Autocorrelation
    
    #Average Amplitude Change
    avg_amp_change = [np.mean(np.abs(np.diff(i))) for i in [ax, ay, az]]
    feat[45:48] = avg_amp_change  # Vị trí lưu Average Amplitude Change
    return feat

def featuresFromBufferNew(at):
    feat_dict = {}
    ax = np.array(at['Acc_X'], dtype=np.float64)
    ay = np.array(at['Acc_Y'], dtype=np.float64)
    az = np.array(at['Acc_Z'], dtype=np.float64)
    # Tính toàn bộ đặc trưng cần thiết theo trục
    feat_dict['Max x'] = np.max(ax)
    feat_dict['SSI x'] = np.sum(ax ** 2)
    feat_dict['Range z'] = np.max(az) - np.min(az)
    feat_dict['MAD x'] = np.mean(np.abs(ax - np.mean(ax)))
    feat_dict['Ene x'] = np.sqrt(np.mean(ax ** 2))
    feat_dict['MAD z'] = np.mean(np.abs(az - np.mean(az)))
    feat_dict['Mean x'] = np.mean(ax)
    feat_dict['aac y'] = np.mean(np.abs(np.diff(ay)))
    feat_dict['Std x'] = np.std(ax)
    feat_dict['SMA x'] = np.sum(np.abs(ax))
    feat_dict['Std y'] = np.std(ay)
    feat_dict['MeaD z'] = np.median(np.abs(az - np.median(az)))
    feat_dict['MeaD x'] = np.median(np.abs(ax - np.median(ax)))
    feat_dict['Ene y'] = np.sqrt(np.mean(ay ** 2))
    feat_dict['Std z'] = np.std(az)
    feat_dict['Mean y'] = np.mean(ay)
    feat_dict['MAD y'] = np.mean(np.abs(ay - np.mean(ay)))
    feat_dict['IQR y'] = np.percentile(ay, 75) - np.percentile(ay, 25)
    feat_dict['IQR x'] = np.percentile(ax, 75) - np.percentile(ax, 25)
    feat_dict['SSI z'] = np.sum(az ** 2)
    feat_dict['Mean z'] = np.mean(az)
    feat_dict['Range x'] = np.max(ax) - np.min(ax)
    feat_dict['Max z'] = np.max(az)
    feat_dict['hc z'] = (
        (np.sqrt(np.var(np.diff(np.diff(az))) / np.var(np.diff(az))) /
         np.sqrt(np.var(np.diff(az)) / np.var(az)))
    )
    feat_dict['aac z'] = np.mean(np.abs(np.diff(az)))
    feat_dict['SMA z'] = np.sum(np.abs(az))
    feat_dict['SMA y'] = np.sum(np.abs(ay))
    feat_dict['aac x'] = np.mean(np.abs(np.diff(ax)))
    feat_dict['Range y'] = np.max(ay) - np.min(ay)
    feat_dict['SSI y'] = np.sum(ay ** 2)

    # Trả về đặc trưng theo đúng thứ tự mong muốn
    feature_order = [
        'Max x', 'SSI x', 'Range z', 'MAD x', 'Ene x', 'MAD z', 'Mean x', 'aac y',
        'Std x', 'SMA x', 'Std y', 'MeaD z', 'MeaD x', 'Ene y', 'Std z', 'Mean y',
        'MAD y', 'IQR y', 'IQR x', 'SSI z', 'Mean z', 'Range x', 'Max z', 'hc z',
        'aac z', 'SMA z', 'SMA y', 'aac x', 'Range y', 'SSI y'
    ]
    
    feat = np.array([feat_dict[f] for f in feature_order])
    return feat

# Thu thập đặc trưng và nhãn
def preprocessing_data(root_dir,excluded_file_NO_DATA,not_considered,non_fall_recovery):
    data_fall = []
    total_fall_files = 0
    miss_file = 0
    data_missFall = []

    # Duyệt qua thư mục tình nguyện viên nam (1XX)
    for volunteer_dir in os.listdir(root_dir):
        if volunteer_dir.startswith('1'):  # Chỉ xét thư mục 1XX
            volunteer_path = os.path.join(root_dir, volunteer_dir)
            if os.path.isdir(volunteer_path):
                # Duyệt qua thư mục Testler Export chứa hành động ngã (9XX)
                testler_export_path = os.path.join(volunteer_path, 'Testler Export')
                if os.path.isdir(testler_export_path):
                    # Duyệt qua các thư mục hành động ngã (9XX) trong Testler Export
                    for action_dir in os.listdir(testler_export_path):
                        if action_dir.startswith('9') and action_dir not in not_considered and action_dir not in non_fall_recovery:
                            action_path = os.path.join(testler_export_path, action_dir)
                            if os.path.isdir(action_path):
                                # Duyệt qua các bài kiểm tra (Test_1, Test_2, ...)
                                for test_dir in os.listdir(action_path):
                                    test_path = os.path.join(action_path, test_dir)

                                    # # Kiểm tra nếu là thư mục Test_XFail thì loại bỏ
                                    # if test_dir.endswith('Fail'):                                
                                    #     data_=[];data=[]
                                    #     data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                                    #     data,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                                    #     if(error_==1):
                                    #         print(f"data_missFall error tai {miss_file}")
                                    #     miss_file=miss_file+1
                                    #     data_missFall =data_missFall+ [data]
                                    #     continue

                                    # # Đường dẫn đến tệp 340535.txt
                                    file_path = os.path.join(test_path, '340535.txt')

                                    # Loại bỏ các tệp excluded_file_NO_DATA
                                    if file_path == excluded_file_NO_DATA:
                                        data_=[];data=[]
                                        data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                                        data,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                                        if(error_==1):
                                            print(f"data_missFall error tai {miss_file}")
                                        miss_file=miss_file+1
                                        data_missFall =data_missFall+ [data]
                                        continue

                                    # Nếu tệp tồn tại, xử lý dữ liệu
                                    if os.path.isfile(file_path):

                                        # Đọc dữ liệu
                                        data_=[];data=[]
                                        data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                                        data,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                                        
                                        if(error_==1): # nhung file loi lien tie
                                            miss_file=miss_file+1
                                            data_missFall =data_missFall+ [data]
                                            print(f"data_missFall error tai {miss_file}")
                                        else:
                                            data = extract_peak_segment_with_noise_padding(data,74,75)
                                            data= data/9.80665
                                            data_fall =data_fall+ [data]
                                            total_fall_files += 1

    print(f"Number of fall files = {total_fall_files}")
    print(f"Number of miss fall files = {miss_file}")
    return data_fall,data_missFall

# %%
# -------------------------------------------------Hàm nhận dạng hành động ngã dựa trên đặc trưng (áp dụng Random Forest Classifier)------------------------------------------------#

# Đường dẫn gốc của cơ sở dữ liệu
possible_dirs = [
    'D:/NCSHieuServer/My Drive/NCSHieu/linh cuu hoa/code python/public falling'
]

# Tìm đường dẫn tồn tại đầu tiên
root_dir = next((d for d in possible_dirs if os.path.exists(d)), None)
save_ = root_dir+'/backup ket qua/'
# Tệp cần loại bỏ
excluded_file_NO_DATA = os.path.join(root_dir, '109', 'Testler Export', '901-OneDogruUzanma', 'Test_6', '340535.txt')

# Danh sách các lớp cần loại bỏ
not_considered = {'903-OneDogruDizlerUzerine', '909-GeriyeDogruOturma', '917-YataktanDusme'}
non_fall_recovery = {'905-OneCabukKalkma', '914-YanaSagliCabukKalkma', '916-YanaSolluCabukKalkma'}

data_falling=[];data_missFalling=[]
data_falling,data_missFalling = preprocessing_data(root_dir,excluded_file_NO_DATA,not_considered,non_fall_recovery)
#===================
#Muc nay chi de test dam bao feature k loi
features = []
for fea in data_falling:
    features.append(featuresFromBuffer(fea))
# X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=1 - RateTrain)
# # Kiểm tra NaN trong từng mảng
contains_nan = [np.isnan(arr).any() for arr in features]

# Kết quả
for i, has_nan in enumerate(contains_nan):
    if has_nan:
        print(f"Array {i} contains NaN: {has_nan}")   
window_size = 3*25
stride = 3*25

class_names = ['WA','RI', 'LY', 'SI','JO','SQ','BD','TO','FA', 'BDP', 'CH', 'LI']
# Out:
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 113 và hàng 114, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# data_missFall error tai 2
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 118 và hàng 119, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 119 và hàng 120, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# data_missFall error tai 3
# Number of fall files = 755
# Number of miss fall files = 3

# %% [markdown]
# Non -fall

# %%
#=====================walking========================
# Đường dẫn gốc của cơ sở dữ liệu


# Lấy danh sách các thư mục con trong root_dir bắt đầu bằng '1'
selected_dirs = [
    os.path.join(root_dir, d) for d in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, d)) and d.startswith('1')
]

# Nối thêm 'Testler Export' vào các thư mục được chọn
testler_export_dirs = [os.path.join(d, 'Testler Export') for d in selected_dirs]

# Lấy các thư mục con bên trong 'Testler Export' bắt đầu bằng '801' hoặc '802'
filtered_subdirs = []
for export_dir in testler_export_dirs:
    if os.path.exists(export_dir):  # Kiểm tra thư mục tồn tại
        subdirs = [
            os.path.join(export_dir, subdir) for subdir in os.listdir(export_dir)
            if os.path.isdir(os.path.join(export_dir, subdir)) and \
               (subdir.startswith('801') or subdir.startswith('802'))
        ]
        filtered_subdirs.extend(subdirs)

list_test = []

for subdir in filtered_subdirs:
    if os.path.exists(subdir):  # Kiểm tra thư mục con tồn tại
        child_dirs = [
            os.path.join(subdir, child) for child in os.listdir(subdir)
            if os.path.isdir(os.path.join(subdir, child))
        ]
        list_test.extend(child_dirs)
        
data_walking = []

# Tìm và đọc các file '340535.txt' hoặc '340535.TXT' trong các thư mục thuộc list_test
for test_path in list_test:
    if os.path.exists(test_path) and os.path.isdir(test_path):
        for file_name in os.listdir(test_path):
            if file_name.lower() == '340535.txt':  # Kiểm tra tên file bất kể chữ hoa/thường
                file_path = os.path.join(test_path, file_name)
                try:
                    data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                    _data_,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                    data = data/9.80665
                    data,_ = filter_acc_axes(_data_, fs=25, std_threshold=0.2)
                    
                    w_data= [data[i:i+window_size].reset_index(drop=True) for i in range(0, int(len(data)), stride) if i+window_size<=int(len(data))]
                    data_walking =data_walking+ w_data
                except Exception as e:
                    print(f"Không thể đọc file {file_path}: {e}")
                        

# Thu thập dữ liệu và phân chia tập huấn luyện/tập kiểm tra

#===================
#Muc nay chi de test dam bao feature k loi
features = []
for fea in data_walking:
    features.append(featuresFromBuffer(fea))
# # Kiểm tra NaN trong từng mảng
contains_nan = [np.isnan(arr).any() for arr in features]

# Kết quả
for i, has_nan in enumerate(contains_nan):
    if has_nan:
        print(f"Array {i} contains NaN: {has_nan}")
# Out:
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 1 và hàng 2, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 2 và hàng 3, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 3 và hàng 4, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 4 và hàng 5, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 1 và hàng 2, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 2 và hàng 3, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 3 và hàng 4, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 4 và hàng 5, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 5 và hàng 6, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 6 và hàng 7, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# ...

# %%
#=====================Jogging========================

# Lấy danh sách các thư mục con trong root_dir bắt đầu bằng '1'
selected_dirs = [
    os.path.join(root_dir, d) for d in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, d)) and d.startswith('1')
]

# Nối thêm 'Testler Export' vào các thư mục được chọn
testler_export_dirs = [os.path.join(d, 'Testler Export') for d in selected_dirs]

filtered_subdirs = []
for export_dir in testler_export_dirs:
    if os.path.exists(export_dir):  # Kiểm tra thư mục tồn tại
        subdirs = [
            os.path.join(export_dir, subdir) for subdir in os.listdir(export_dir)
            if os.path.isdir(os.path.join(export_dir, subdir)) and \
               (subdir.startswith('803'))
        ]
        filtered_subdirs.extend(subdirs)

list_test = []

for subdir in filtered_subdirs:
    if os.path.exists(subdir):  # Kiểm tra thư mục con tồn tại
        child_dirs = [
            os.path.join(subdir, child) for child in os.listdir(subdir)
            if os.path.isdir(os.path.join(subdir, child))
        ]
        list_test.extend(child_dirs)
        
data_jogging = []
# Tìm và đọc các file '340535.txt' hoặc '340535.TXT' trong các thư mục thuộc list_test
for test_path in list_test:
    if os.path.exists(test_path) and os.path.isdir(test_path):
        for file_name in os.listdir(test_path):
            if file_name.lower() == '340535.txt':  # Kiểm tra tên file bất kể chữ hoa/thường
                file_path = os.path.join(test_path, file_name)
                try:
                    data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                    _data_,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                    _data_ = _data_/9.80665
                    data,_ = filter_acc_axes(_data_, fs=25, std_threshold=0.2)
                    w_data= [data[i:i+window_size].reset_index(drop=True) for i in range(0, int(len(data)), stride) if i+window_size<=int(len(data))]
                    data_jogging =data_jogging+ w_data
                except Exception as e:
                    print(f"Không thể đọc file {file_path}: {e}")
                        

#===================
#Muc nay chi de test dam bao feature k loi
features = []
for fea in data_jogging:
    features.append(featuresFromBuffer(fea))
# # Kiểm tra NaN trong từng mảng
contains_nan = [np.isnan(arr).any() for arr in features]

# Kết quả
for i, has_nan in enumerate(contains_nan):
    if has_nan:
        print(f"Array {i} contains NaN: {has_nan}")   
#============================
# Out:
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 355 và hàng 356, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']

# %%
# ==================squatting==============================
# Đường dẫn gốc của cơ sở dữ liệu

# Lấy danh sách các thư mục con trong root_dir bắt đầu bằng '1'
selected_dirs = [
    os.path.join(root_dir, d) for d in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, d)) and d.startswith('1')
]

# Nối thêm 'Testler Export' vào các thư mục được chọn
testler_export_dirs = [os.path.join(d, 'Testler Export') for d in selected_dirs]

filtered_subdirs = []
for export_dir in testler_export_dirs:
    if os.path.exists(export_dir):  # Kiểm tra thư mục tồn tại
        subdirs = [
            os.path.join(export_dir, subdir) for subdir in os.listdir(export_dir)
            if os.path.isdir(os.path.join(export_dir, subdir)) and \
               (subdir.startswith('804'))
        ]
        filtered_subdirs.extend(subdirs)
        
list_test = []

for subdir in filtered_subdirs:
    if os.path.exists(subdir):  # Kiểm tra thư mục con tồn tại
        child_dirs = [
            os.path.join(subdir, child) for child in os.listdir(subdir)
            if os.path.isdir(os.path.join(subdir, child))
        ]
        list_test.extend(child_dirs)
        
data_squatting = []

# Tìm và đọc các file '340535.txt' hoặc '340535.TXT' trong các thư mục thuộc list_test
for test_path in list_test:
    if os.path.exists(test_path) and os.path.isdir(test_path):
        for file_name in os.listdir(test_path):
            if file_name.lower() == '340535.txt':  # Kiểm tra tên file bất kể chữ hoa/thường
                file_path = os.path.join(test_path, file_name)
                try:
                    data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                    data,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                    data = data.groupby(data.index // 2).mean().reset_index(drop=True)
                    data,_ = filter_acc_axes(_data_, fs=25, std_threshold=0.2) 
                    if len(data)>50:
                        data = extract_peak_segment_with_noise_padding(data,37,37)
                        data = data/9.80665
                        data_squatting =data_squatting+ [data]
                except Exception as e:
                    print(f"Không thể đọc file {file_path}: {e}")
                        

#===================
#Muc nay chi de test dam bao feature k loi
features = []
for fea in data_squatting:
    features.append(featuresFromBuffer(fea))
# Kiểm tra NaN trong từng mảng
contains_nan = [np.isnan(arr).any() for arr in features]

# Kết quả
for i, has_nan in enumerate(contains_nan):
    if has_nan:
        print(f"Array {i} contains NaN: {has_nan}")

# %%
# ==================Bending==============================

# Lấy danh sách các thư mục con trong root_dir bắt đầu bằng '1'
selected_dirs = [
    os.path.join(root_dir, d) for d in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, d)) and d.startswith('1')
]

# Nối thêm 'Testler Export' vào các thư mục được chọn
testler_export_dirs = [os.path.join(d, 'Testler Export') for d in selected_dirs]

filtered_subdirs = []
for export_dir in testler_export_dirs:
    if os.path.exists(export_dir):  # Kiểm tra thư mục tồn tại
        subdirs = [
            os.path.join(export_dir, subdir) for subdir in os.listdir(export_dir)
            if os.path.isdir(os.path.join(export_dir, subdir)) and \
               ( subdir.startswith('805'))
        ]
        filtered_subdirs.extend(subdirs)
        
list_test = []

for subdir in filtered_subdirs:
    if os.path.exists(subdir):  # Kiểm tra thư mục con tồn tại
        child_dirs = [
            os.path.join(subdir, child) for child in os.listdir(subdir)
            if os.path.isdir(os.path.join(subdir, child))
        ]
        list_test.extend(child_dirs)
        
data_bending = []

# Tìm và đọc các file '340535.txt' hoặc '340535.TXT' trong các thư mục thuộc list_test
for test_path in list_test:
    if os.path.exists(test_path) and os.path.isdir(test_path):
        for file_name in os.listdir(test_path):
            if file_name.lower() == '340535.txt':  # Kiểm tra tên file bất kể chữ hoa/thường
                file_path = os.path.join(test_path, file_name)
                try:
                    data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                    data,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                    data = data/9.80665
                    w_data= [data[i:i+window_size].reset_index(drop=True) for i in range(0, int(len(data)), stride) if i+window_size<=int(len(data))]
                    data_bending =data_bending+ w_data
                except Exception as e:
                    print(f"Không thể đọc file {file_path}: {e}")

#===================
#Muc nay chi de test dam bao feature k loi
features = []
for fea in data_bending:
    features.append(featuresFromBuffer(fea))
# Kiểm tra NaN trong từng mảng
contains_nan = [np.isnan(arr).any() for arr in features]

# Kết quả
for i, has_nan in enumerate(contains_nan):
    if has_nan:
        print(f"Array {i} contains NaN: {has_nan}")

# %%
# ==================Bending pickup==============================
# Đường dẫn gốc của cơ sở dữ liệu

# Lấy danh sách các thư mục con trong root_dir bắt đầu bằng '1'
selected_dirs = [
    os.path.join(root_dir, d) for d in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, d)) and d.startswith('1')
]

# Nối thêm 'Testler Export' vào các thư mục được chọn
testler_export_dirs = [os.path.join(d, 'Testler Export') for d in selected_dirs]

filtered_subdirs = []
for export_dir in testler_export_dirs:
    if os.path.exists(export_dir):  # Kiểm tra thư mục tồn tại
        subdirs = [
            os.path.join(export_dir, subdir) for subdir in os.listdir(export_dir)
            if os.path.isdir(os.path.join(export_dir, subdir)) and \
               (subdir.startswith('806'))
        ]
        filtered_subdirs.extend(subdirs)
        
list_test = []

for subdir in filtered_subdirs:
    if os.path.exists(subdir):  # Kiểm tra thư mục con tồn tại
        child_dirs = [
            os.path.join(subdir, child) for child in os.listdir(subdir)
            if os.path.isdir(os.path.join(subdir, child))
        ]
        list_test.extend(child_dirs)
        
data_BendPick= []

# Tìm và đọc các file '340535.txt' hoặc '340535.TXT' trong các thư mục thuộc list_test
for test_path in list_test:
    if os.path.exists(test_path) and os.path.isdir(test_path):
        for file_name in os.listdir(test_path):
            if file_name.lower() == '340535.txt':  # Kiểm tra tên file bất kể chữ hoa/thường
                file_path = os.path.join(test_path, file_name)
                try:
                    data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                    _data_,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                    data,_ = filter_acc_axes(_data_, fs=25, std_threshold=0.2)                   
                    data = extract_peak_segment_with_noise_padding(data,37,37)
                    data = data/9.80665
                    if len(data)>50:
                        data_BendPick =data_BendPick+ [data]
                except Exception as e:
                    print(f"Không thể đọc file {file_path}: {e}")
                        

#===================
#Muc nay chi de test dam bao feature k loi
features = []
for fea in data_BendPick:
    features.append(featuresFromBuffer(fea))
# Kiểm tra NaN trong từng mảng
contains_nan = [np.isnan(arr).any() for arr in features]

# Kết quả
for i, has_nan in enumerate(contains_nan):
    if has_nan:
        print(f"Array {i} contains NaN: {has_nan}")

# %%
# ==================Limp==============================

# Lấy danh sách các thư mục con trong root_dir bắt đầu bằng '1'
selected_dirs = [
    os.path.join(root_dir, d) for d in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, d)) and d.startswith('1')
]

# Nối thêm 'Testler Export' vào các thư mục được chọn
testler_export_dirs = [os.path.join(d, 'Testler Export') for d in selected_dirs]

filtered_subdirs = []
for export_dir in testler_export_dirs:
    if os.path.exists(export_dir):  # Kiểm tra thư mục tồn tại
        subdirs = [
            os.path.join(export_dir, subdir) for subdir in os.listdir(export_dir)
            if os.path.isdir(os.path.join(export_dir, subdir)) and \
               (subdir.startswith('807'))
        ]
        filtered_subdirs.extend(subdirs)
        
list_test = []

for subdir in filtered_subdirs:
    if os.path.exists(subdir):  # Kiểm tra thư mục con tồn tại
        child_dirs = [
            os.path.join(subdir, child) for child in os.listdir(subdir)
            if os.path.isdir(os.path.join(subdir, child))
        ]
        list_test.extend(child_dirs)
        
data_limp = []

# Tìm và đọc các file '340535.txt' hoặc '340535.TXT' trong các thư mục thuộc list_test
for test_path in list_test:
    if os.path.exists(test_path) and os.path.isdir(test_path):
        for file_name in os.listdir(test_path):
            if file_name.lower() == '340535.txt':  # Kiểm tra tên file bất kể chữ hoa/thường
                file_path = os.path.join(test_path, file_name)
                try:
                    data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                    _data_,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                    data,_ = filter_acc_axes(_data_, fs=25, std_threshold=0.2)
                    data = data/9.80665
                    w_data= [data[i:i+window_size].reset_index(drop=True) for i in range(0, int(len(data)), stride) if i+window_size<=int(len(data))]
                    data_limp =data_limp+ w_data
                except Exception as e:
                    print(f"Không thể đọc file {file_path}: {e}")
                        

#===================
#Muc nay chi de test dam bao feature k loi
features = []
for fea in data_limp:
    features.append(featuresFromBuffer(fea))
# Kiểm tra NaN trong từng mảng
contains_nan = [np.isnan(arr).any() for arr in features]

# Kết quả
for i, has_nan in enumerate(contains_nan):
    if has_nan:
        print(f"Array {i} contains NaN: {has_nan}")
# Out:
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 44 và hàng 45, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']

# %%
# ==================stumbling==============================

# Lấy danh sách các thư mục con trong root_dir bắt đầu bằng '1'
selected_dirs = [
    os.path.join(root_dir, d) for d in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, d)) and d.startswith('1')
]

# Nối thêm 'Testler Export' vào các thư mục được chọn
testler_export_dirs = [os.path.join(d, 'Testler Export') for d in selected_dirs]

filtered_subdirs = []
for export_dir in testler_export_dirs:
    if os.path.exists(export_dir):  # Kiểm tra thư mục tồn tại
        subdirs = [
            os.path.join(export_dir, subdir) for subdir in os.listdir(export_dir)
            if os.path.isdir(os.path.join(export_dir, subdir)) and \
               (subdir.startswith('808'))
        ]
        filtered_subdirs.extend(subdirs)
        
list_test = []

for subdir in filtered_subdirs:
    if os.path.exists(subdir):  # Kiểm tra thư mục con tồn tại
        child_dirs = [
            os.path.join(subdir, child) for child in os.listdir(subdir)
            if os.path.isdir(os.path.join(subdir, child))
        ]
        list_test.extend(child_dirs)
        
data_stumbling= []

# Tìm và đọc các file '340535.txt' hoặc '340535.TXT' trong các thư mục thuộc list_test
for test_path in list_test:
    if os.path.exists(test_path) and os.path.isdir(test_path):
        for file_name in os.listdir(test_path):
            if file_name.lower() == '340535.txt':  # Kiểm tra tên file bất kể chữ hoa/thường
                file_path = os.path.join(test_path, file_name)
                try:
                    data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                    _data_,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                    data,_ = filter_acc_axes(_data_, fs=25, std_threshold=0.2)
                    if len(data)>1:
                        data = extract_peak_segment_with_noise_padding(data,37,37)
                        data = data/9.80665
                        data_stumbling =data_stumbling+ [data]
                except Exception as e:
                    print(f"Không thể đọc file {file_path}: {e}")
                        

#===================
#Muc nay chi de test dam bao feature k loi
features = []
for fea in data_stumbling:
    features.append(featuresFromBuffer(fea))
# Kiểm tra NaN trong từng mảng
contains_nan = [np.isnan(arr).any() for arr in features]

# Kết quả
for i, has_nan in enumerate(contains_nan):
    if has_nan:
        print(f"Array {i} contains NaN: {has_nan}")   
#============================
# Out:
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 513 và hàng 514, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 514 và hàng 515, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 515 và hàng 516, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 516 và hàng 517, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 517 và hàng 518, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 518 và hàng 519, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 519 và hàng 520, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 520 và hàng 521, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 521 và hàng 522, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 522 và hàng 523, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']
# ...

# %%
# ==================tripover==============================
# Đường dẫn gốc của cơ sở dữ liệu

# Lấy danh sách các thư mục con trong root_dir bắt đầu bằng '1'
selected_dirs = [
    os.path.join(root_dir, d) for d in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, d)) and d.startswith('1')
]

# Nối thêm 'Testler Export' vào các thư mục được chọn
testler_export_dirs = [os.path.join(d, 'Testler Export') for d in selected_dirs]

filtered_subdirs = []
for export_dir in testler_export_dirs:
    if os.path.exists(export_dir):  # Kiểm tra thư mục tồn tại
        subdirs = [
            os.path.join(export_dir, subdir) for subdir in os.listdir(export_dir)
            if os.path.isdir(os.path.join(export_dir, subdir)) and \
               (subdir.startswith('809'))
        ]
        filtered_subdirs.extend(subdirs)
        
list_test = []

for subdir in filtered_subdirs:
    if os.path.exists(subdir):  # Kiểm tra thư mục con tồn tại
        child_dirs = [
            os.path.join(subdir, child) for child in os.listdir(subdir)
            if os.path.isdir(os.path.join(subdir, child))
        ]
        list_test.extend(child_dirs)
        
data_tripover= []

# Tìm và đọc các file '340535.txt' hoặc '340535.TXT' trong các thư mục thuộc list_test
for test_path in list_test:
    if os.path.exists(test_path) and os.path.isdir(test_path):
        for file_name in os.listdir(test_path):
            if file_name.lower() == '340535.txt':  # Kiểm tra tên file bất kể chữ hoa/thường
                file_path = os.path.join(test_path, file_name)
                try:
                    data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                    _data_,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                    data,_ = filter_acc_axes(_data_, fs=25, std_threshold=0.2)
                    if len(data)>50:
                        data = data/9.80665
                        data = extract_peak_segment_with_noise_padding(data,37,37)
                        data_tripover =data_tripover+ [data]
                except Exception as e:
                    print(f"Không thể đọc file {file_path}: {e}")
                        

#===================
#Muc nay chi de test dam bao feature k loi
features = []
for fea in data_tripover:
    features.append(featuresFromBuffer(fea))
# Kiểm tra NaN trong từng mảng
contains_nan = [np.isnan(arr).any() for arr in features]

# Kết quả
for i, has_nan in enumerate(contains_nan):
    if has_nan:
        print(f"Array {i} contains NaN: {has_nan}")   
#============================
# Out:
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 1 và hàng 2, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']

# %%
# ==================coughing==============================

# Lấy danh sách các thư mục con trong root_dir bắt đầu bằng '1'
selected_dirs = [
    os.path.join(root_dir, d) for d in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, d)) and d.startswith('1')
]

# Nối thêm 'Testler Export' vào các thư mục được chọn
testler_export_dirs = [os.path.join(d, 'Testler Export') for d in selected_dirs]

filtered_subdirs = []
for export_dir in testler_export_dirs:
    if os.path.exists(export_dir):  # Kiểm tra thư mục tồn tại
        subdirs = [
            os.path.join(export_dir, subdir) for subdir in os.listdir(export_dir)
            if os.path.isdir(os.path.join(export_dir, subdir)) and \
               (subdir.startswith('810'))
        ]
        filtered_subdirs.extend(subdirs)
        
list_test = []

for subdir in filtered_subdirs:
    if os.path.exists(subdir):  # Kiểm tra thư mục con tồn tại
        child_dirs = [
            os.path.join(subdir, child) for child in os.listdir(subdir)
            if os.path.isdir(os.path.join(subdir, child))
        ]
        list_test.extend(child_dirs)
        
data_coughing= []

# Tìm và đọc các file '340535.txt' hoặc '340535.TXT' trong các thư mục thuộc list_test
for test_path in list_test:
    if os.path.exists(test_path) and os.path.isdir(test_path):
        for file_name in os.listdir(test_path):
            if file_name.lower() == '340535.txt':  # Kiểm tra tên file bất kể chữ hoa/thường
                file_path = os.path.join(test_path, file_name)
                try:
                    data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                    data,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                    # data,_ = filter_acc_axes(_data_, fs=25, std_threshold=0.1)
                    if len(data)>50:
                        data = data/9.80665
                        data = extract_peak_segment_with_noise_padding(data,37,37)
                        data_coughing =data_coughing+ [data]
                    else:
                        print(file_path,"*************************")
                except Exception as e:
                    print(f"Không thể đọc file {file_path}: {e}")
                        

#===================
#Muc nay chi de test dam bao feature k loi
features = []
for fea in data_coughing:
    features.append(featuresFromBuffer(fea))
# Kiểm tra NaN trong từng mảng
contains_nan = [np.isnan(arr).any() for arr in features]

# Kết quả
for i, has_nan in enumerate(contains_nan):
    if has_nan:
        print(f"Array {i} contains NaN: {has_nan}")

# %%
# ==================Sitting==============================

# Lấy danh sách các thư mục con trong root_dir bắt đầu bằng '1'
selected_dirs = [
    os.path.join(root_dir, d) for d in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, d)) and d.startswith('1')
]

# Nối thêm 'Testler Export' vào các thư mục được chọn
testler_export_dirs = [os.path.join(d, 'Testler Export') for d in selected_dirs]

filtered_subdirs = []
for export_dir in testler_export_dirs:
    if os.path.exists(export_dir):  # Kiểm tra thư mục tồn tại
        subdirs = [
            os.path.join(export_dir, subdir) for subdir in os.listdir(export_dir)
            if os.path.isdir(os.path.join(export_dir, subdir)) and \
               (subdir.startswith('811') or subdir.startswith('814') or subdir.startswith('812') or subdir.startswith('813'))
        ]
        filtered_subdirs.extend(subdirs)
        
list_test = []

for subdir in filtered_subdirs:
    if os.path.exists(subdir):  # Kiểm tra thư mục con tồn tại
        child_dirs = [
            os.path.join(subdir, child) for child in os.listdir(subdir)
            if os.path.isdir(os.path.join(subdir, child))
        ]
        list_test.extend(child_dirs)
        
data_Sitting= []

# Tìm và đọc các file '340535.txt' hoặc '340535.TXT' trong các thư mục thuộc list_test
for test_path in list_test:
    if os.path.exists(test_path) and os.path.isdir(test_path):
        for file_name in os.listdir(test_path):
            if file_name.lower() == '340535.txt':  # Kiểm tra tên file bất kể chữ hoa/thường
                file_path = os.path.join(test_path, file_name)
                try:
                    data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                    _data_,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                    data,_ = filter_acc_axes(_data_, fs=25, std_threshold=0.2)
                    if len(data)>50:
                        data = extract_peak_segment_with_noise_padding(data,50,24)
                        data = data/9.80665
                    if len(data)>1:
                        data_Sitting =data_Sitting+ [data]
                    else:
                        print(file_path,"*************************")
                except Exception as e:
                    print(f"Không thể đọc file {file_path}: {e}")
                        

#===================
#Muc nay chi de test dam bao feature k loi
features = []
for fea in data_Sitting:
    features.append(featuresFromBuffer(fea))
# Kiểm tra NaN trong từng mảng
contains_nan = [np.isnan(arr).any() for arr in features]

# Kết quả
for i, has_nan in enumerate(contains_nan):
    if has_nan:
        print(f"Array {i} contains NaN: {has_nan}")   
#============================
# Out:
# Hai hàng liên tiếp chứa NaN ở cùng cột: hàng 150 và hàng 151, cột: ['Acc_X', 'Acc_Y', 'Acc_Z']

# %%
# ==================Lying==============================

# Lấy danh sách các thư mục con trong root_dir bắt đầu bằng '1'
selected_dirs = [
    os.path.join(root_dir, d) for d in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, d)) and d.startswith('1')
]

# Nối thêm 'Testler Export' vào các thư mục được chọn
testler_export_dirs = [os.path.join(d, 'Testler Export') for d in selected_dirs]

filtered_subdirs = []
for export_dir in testler_export_dirs:
    if os.path.exists(export_dir):  # Kiểm tra thư mục tồn tại
        subdirs = [
            os.path.join(export_dir, subdir) for subdir in os.listdir(export_dir)
            if os.path.isdir(os.path.join(export_dir, subdir)) and \
               (subdir.startswith('815'))
        ]
        filtered_subdirs.extend(subdirs)
        
list_test = []

for subdir in filtered_subdirs:
    if os.path.exists(subdir):  # Kiểm tra thư mục con tồn tại
        child_dirs = [
            os.path.join(subdir, child) for child in os.listdir(subdir)
            if os.path.isdir(os.path.join(subdir, child))
        ]
        list_test.extend(child_dirs)
        
data_Lying= []

# Tìm và đọc các file '340535.txt' hoặc '340535.TXT' trong các thư mục thuộc list_test
for test_path in list_test:
    if os.path.exists(test_path) and os.path.isdir(test_path):
        for file_name in os.listdir(test_path):
            if file_name.lower() == '340535.txt':  # Kiểm tra tên file bất kể chữ hoa/thường
                file_path = os.path.join(test_path, file_name)
                try:
                    data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                    _data_,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                    data,_ = filter_acc_axes(_data_, fs=25, std_threshold=0.2)
                    if len(data)>50:
                        data = extract_peak_segment_with_noise_padding(data,50,24)
                        data = data/9.80665
                        data_Lying =data_Lying+ [data]
                    else:
                        print(file_path,"*************************")
                except Exception as e:
                    print(f"Không thể đọc file {file_path}: {e}")
                        
#===================
#Muc nay chi de test dam bao feature k loi
features = []
for fea in data_Lying:
    features.append(featuresFromBuffer(fea))
# Kiểm tra NaN trong từng mảng
contains_nan = [np.isnan(arr).any() for arr in features]

# Kết quả
for i, has_nan in enumerate(contains_nan):
    if has_nan:
        print(f"Array {i} contains NaN: {has_nan}")   
#============================

# %%
# ==================Rising==============================

# Lấy danh sách các thư mục con trong root_dir bắt đầu bằng '1'
selected_dirs = [
    os.path.join(root_dir, d) for d in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, d)) and d.startswith('1')
]

# Nối thêm 'Testler Export' vào các thư mục được chọn
testler_export_dirs = [os.path.join(d, 'Testler Export') for d in selected_dirs]

filtered_subdirs = []
for export_dir in testler_export_dirs:
    if os.path.exists(export_dir):  # Kiểm tra thư mục tồn tại
        subdirs = [
            os.path.join(export_dir, subdir) for subdir in os.listdir(export_dir)
            if os.path.isdir(os.path.join(export_dir, subdir)) and \
               (subdir.startswith('816'))
        ]
        filtered_subdirs.extend(subdirs)
        
list_test = []

for subdir in filtered_subdirs:
    if os.path.exists(subdir):  # Kiểm tra thư mục con tồn tại
        child_dirs = [
            os.path.join(subdir, child) for child in os.listdir(subdir)
            if os.path.isdir(os.path.join(subdir, child))
        ]
        list_test.extend(child_dirs)
        
data_Rising= []

# Tìm và đọc các file '340535.txt' hoặc '340535.TXT' trong các thư mục thuộc list_test
for test_path in list_test:
    if os.path.exists(test_path) and os.path.isdir(test_path):
        for file_name in os.listdir(test_path):
            if file_name.lower() == '340535.txt':  # Kiểm tra tên file bất kể chữ hoa/thường
                file_path = os.path.join(test_path, file_name)
                try:
                    data_ = pd.read_csv(file_path, sep='\s+', skiprows=6, names=columns)
                    _data_,error_=handle_nan_rows(data_[['Acc_X','Acc_Y','Acc_Z']])
                    data = data/9.80665
                    data,_ = filter_acc_axes(_data_, fs=25, std_threshold=0.2)
                    
                    if len(data)>50:
                        data = extract_peak_segment_with_noise_padding(data,45,29)
                        
                        data_Rising =data_Rising+ [data]
                    else:
                        print(file_path,"*************************")
                except Exception as e:
                    print(f"Không thể đọc file {file_path}: {e}")

#===================
#Muc nay chi de test dam bao feature k loi
features = []
for fea in data_Rising:
    features.append(featuresFromBuffer(fea))
# Kiểm tra NaN trong từng mảng
contains_nan = [np.isnan(arr).any() for arr in features]

# Kết quả
for i, has_nan in enumerate(contains_nan):
    if has_nan:
        print(f"Array {i} contains NaN: {has_nan}")   
#============================

# %%
random_state_=33

RateTrain = 0.6
#============================
train_Falling =[];test_Falling=[]        
test_Falling, train_Falling = train_test_split(data_falling, test_size=RateTrain,random_state=random_state_)
print('\n test_Falling:', len(test_Falling))
print('train_Falling:', len(train_Falling))
        
#============================
train_Walking =[];test_Walking=[]          
test_Walking, train_Walking = train_test_split(data_walking, test_size=RateTrain,random_state=random_state_)
print('\n test_Walking:', len(test_Walking))
print('train_Walking:', len(train_Walking))

train_Jogging =[];test_Jogging=[]          
test_Jogging, train_Jogging = train_test_split(data_jogging, test_size=RateTrain,random_state=random_state_)
print('\n test_Jogging:', len(test_Jogging))
print('train_Jogging:', len(train_Jogging))

#============================
train_Squatting =[];test_Squatting=[]          
test_Squatting, train_Squatting = train_test_split(data_squatting, test_size=RateTrain,random_state=random_state_)
print('\n test_Squatting:', len(test_Squatting))
print('train_Squatting:', len(train_Squatting))

#============================
train_Bending =[];test_Bending=[]          
test_Bending, train_Bending = train_test_split(data_bending, test_size=RateTrain,random_state=random_state_)
print('\n test_Bending:', len(test_Bending))
print('train_Bending:', len(train_Bending))

train_Sitting =[];test_Sitting=[]          
test_Sitting, train_Sitting = train_test_split(data_Sitting, test_size=RateTrain,random_state=random_state_)
print('\n test_Sitting:', len(test_Sitting))
print('train_Sitting:', len(train_Sitting))

train_Lying =[];test_Lying=[]          
test_Lying, train_Lying = train_test_split(data_Lying, test_size=RateTrain,random_state=random_state_)
print('\n test_Lying:', len(test_Lying))
print('train_Lying:', len(train_Lying))

train_Rising =[];test_Rising=[]          
test_Rising, train_Rising = train_test_split(data_Rising, test_size=RateTrain,random_state=random_state_)
print('\n test_Rising:', len(test_Rising))
print('train_Rising:', len(train_Rising))

#============================
train_coughing =[];test_coughing=[]          
test_coughing, train_coughing = train_test_split(data_coughing, test_size=RateTrain,random_state=random_state_)
print('\n test_coughing:', len(test_coughing))
print('train_coughing:', len(train_coughing))

train_tripover =[];test_tripover=[]          
test_tripover, train_tripover = train_test_split(data_tripover, test_size=RateTrain,random_state=random_state_)
print('\n test_tripover:', len(test_tripover))
print('train_tripover:', len(train_tripover))

train_stumbling =[];test_stumbling=[]          
test_stumbling, train_stumbling = train_test_split(data_stumbling, test_size=RateTrain,random_state=random_state_)
print('\n test_stumbling:', len(test_stumbling))
print('train_stumbling:', len(train_stumbling))

#============================
train_limp =[];test_limp=[]          
test_limp, train_limp = train_test_split(data_limp, test_size=RateTrain,random_state=random_state_)
print('\n test_limp:', len(test_limp))
print('train_limp:', len(train_limp))


#============================
train_BendPick =[];test_BendPick=[]          
test_BendPick, train_BendPick = train_test_split(data_BendPick, test_size=RateTrain,random_state=random_state_)
print('\n test_BendPick:', len(test_BendPick))
print('train_BendPick:', len(train_BendPick))

data_train = []
label_train = []
for acts in train_Walking:
    data_train.append(pd.DataFrame(acts))
    label_train.append(0)

for acts in train_Rising:
    data_train.append(pd.DataFrame(acts))
    label_train.append(1)

for acts in train_Lying:
    data_train.append(pd.DataFrame(acts))
    label_train.append(2)

for acts in train_Sitting:
    data_train.append(pd.DataFrame(acts))
    label_train.append(3)

for acts in train_Jogging:
    data_train.append(pd.DataFrame(acts))
    label_train.append(4)

for acts in train_Squatting:
    data_train.append(pd.DataFrame(acts))
    label_train.append(5)

for acts in train_Bending:
    data_train.append(pd.DataFrame(acts))
    label_train.append(6)

for acts in train_stumbling:
    data_train.append(pd.DataFrame(acts))
    label_train.append(7)

for acts in train_tripover:
    data_train.append(pd.DataFrame(acts))
    label_train.append(7)

for acts in train_Falling:
    data_train.append(pd.DataFrame(acts))
    label_train.append(8)

for acts in train_BendPick:
    data_train.append(pd.DataFrame(acts))
    label_train.append(9)

for acts in train_coughing:
    data_train.append(pd.DataFrame(acts))
    label_train.append(10)
    
for acts in train_limp:
    data_train.append(pd.DataFrame(acts))
    label_train.append(11)
    


data_test = []
label_test = []
for acts in test_Walking:
    data_test.append(pd.DataFrame(acts))
    label_test.append(0)

for acts in test_Rising:
    data_test.append(pd.DataFrame(acts))
    label_test.append(1)

for acts in test_Lying:
    data_test.append(pd.DataFrame(acts))
    label_test.append(2)

for acts in test_Sitting:
    data_test.append(pd.DataFrame(acts))
    label_test.append(3)

for acts in test_Jogging:
    data_test.append(pd.DataFrame(acts))
    label_test.append(4)

for acts in test_Squatting:
    data_test.append(pd.DataFrame(acts))
    label_test.append(5)

for acts in test_Bending:
    data_test.append(pd.DataFrame(acts))
    label_test.append(6)

for acts in test_stumbling:
    data_test.append(pd.DataFrame(acts))
    label_test.append(7)
    
for acts in test_tripover:
    data_test.append(pd.DataFrame(acts))
    label_test.append(7)

for acts in test_Falling:
    data_test.append(pd.DataFrame(acts))
    label_test.append(8)

for acts in test_BendPick:
    data_test.append(pd.DataFrame(acts))
    label_test.append(9)

for acts in test_coughing:
    data_test.append(pd.DataFrame(acts))
    label_test.append(10)
    
for acts in test_limp:
    data_test.append(pd.DataFrame(acts))
    label_test.append(11)

train_features = []; test_features=[]
for action in data_train:
    feat = featuresFromBuffer(action)
    train_features.append(feat)
for action in data_test:
    feat = featuresFromBuffer(action)
    test_features.append(feat) 

print('\n train_features:', len(train_features))
print('test_features:', len(test_features))
    
clf4 = RandomForestClassifier(criterion='entropy',class_weight='balanced',n_jobs=-1, n_estimators=18,max_depth=14,max_features='sqrt',bootstrap=True, random_state=4).fit(train_features, label_train)
print('Accuracy of RF classifier on training set: {:.3f}'
     .format(clf4.score(train_features, label_train)))
print('Accuracy of RF classifier on test set: {:.3f}'
     .format(clf4.score(test_features, label_test)))
predicted4 = clf4.predict(test_features)
confusion_test4 = confusion_matrix(label_test, predicted4)


# # Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_test4, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names, cbar_kws={'label': 'Scale'}, annot_kws={"size": 13})

# Set labels and title with font size 14
plt.xlabel('Predicted', fontsize=13)
plt.ylabel('True', fontsize=13)
plt.title('Confusion Matrix for Random Forest', fontsize=12)
# Rotate x-axis labels by 20 degrees
plt.xticks(rotation=30,fontsize=12)
plt.yticks(fontsize=12)
# Show plot
plt.show()
# Out:
#  test_Falling: 302
# train_Falling: 453
#
#  test_Walking: 166
# train_Walking: 251
#
#  test_Jogging: 37
# train_Jogging: 56
#
#  test_Squatting: 22
# train_Squatting: 33
#
#  test_Bending: 107
# train_Bending: 162
#
#  test_Sitting: 88
# train_Sitting: 132
#
#  test_Lying: 22
# train_Lying: 33
#
#  test_Rising: 22
# train_Rising: 34
#
#  test_coughing: 22
# train_coughing: 34
#
#  test_tripover: 22
# train_tripover: 33
#
#  test_stumbling: 22
# train_stumbling: 33
#
#  test_limp: 89
# train_limp: 134
#
#  test_BendPick: 22
# train_BendPick: 33
#
#  train_features: 1421
# test_features: 943
# Accuracy of RF classifier on training set: 0.999
# Accuracy of RF classifier on test set: 0.987

# %%
max_score = 0
iteration = 0  # Đếm số lần lặp
target_score = 98.3  # Ngưỡng độ chính xác

print(f"Iteration Training model...")

#============
param_dist = {
    '_estimators': range(14, 50, 1),  # Số lượng cây từ 10 đến 20
    '_depth': range(12, 50,1),      # Độ sâu tối đa từ 10 đến 30
    '_random':range(1,100,1)       # ngau nhien 1:30
}

# Khởi tạo một DataFrame để lưu kết quả
results = []
_score = 0
# Thực hiện Grid Search thủ công
for _estimators in param_dist['_estimators']:
    for _depth in param_dist['_depth']:
        for _random in param_dist['_random']:
            # Huấn luyện mô hình với tham số hiện tại
            clf4 = RandomForestClassifier(criterion='entropy',n_jobs=-1, n_estimators=_estimators, max_depth=_depth,max_features='sqrt',class_weight='balanced', 
                                            bootstrap=True, random_state=_random).fit(train_features, label_train)
            
            # Dự đoán trên tập kiểm tra
            predicted_RF = clf4.predict(test_features)
            
            # Tính toán độ chính xác
            score = clf4.score(test_features, label_test)
            
            if _score < score:
                _score = score
                print("n_estimators=" , _estimators, "; max_depth= " , _depth, "; random_state= " , _random)
                print(f"Accuracy of RF classifier on test set: {round(score * 100, 1)}")
                def model_size_in_bytes(model):
                    return len(pickle.dumps(model))
                print(f"Model size (MB): {round(model_size_in_bytes(clf4)/1024**2, 3)}")

            # Lưu kết quả
            results.append({'n_estimators': _estimators, 'max_depth': _depth, 'random_state': _random, 'score': round(score * 100, 1)})
            del clf4
            if _score>= target_score:
                break
            
results_df = pd.DataFrame(results)

# Tìm giá trị score cao nhất
max_score = results_df['score'].max()


# Lưu kết quả tốt nhất
high_score_df = results_df[results_df['score'] == max_score]
if len(high_score_df) > 0:
    best_params = high_score_df.iloc[0]
else:
    best_params = None

# results_df.to_csv(save_+"search_results_SLFDA.csv", index=False)
# Out:
# Iteration Training model...
# n_estimators= 14 ; max_depth=  12 ; random_state=  1
# Accuracy of RF classifier on test set: 98.7
# Model size (MB): 0.243
# n_estimators= 14 ; max_depth=  12 ; random_state=  6
# Accuracy of RF classifier on test set: 98.8
# Model size (MB): 0.256
# n_estimators= 14 ; max_depth=  12 ; random_state=  24
# Accuracy of RF classifier on test set: 98.9
# Model size (MB): 0.253
# n_estimators= 14 ; max_depth=  12 ; random_state=  59
# Accuracy of RF classifier on test set: 99.0
# Model size (MB): 0.247

# %%
# # Đọc đặc trưng
# train_features = joblib.load(save_ + 'SFDLA_train_features.pkl')
# test_features = joblib.load(save_ + 'SFDLA_test_features.pkl')
# label_train = joblib.load(save_ + 'SFDLA_label_train.pkl')
# label_test = joblib.load(save_ + 'SFDLA_label_test.pkl')
# # clf4 = joblib.load(save_ + 'clf4.pkl')
# best_params = joblib.load(save_ + 'best_params.pkl')

# %%
best_params
# Out:
# n_estimators    14.0
# max_depth       12.0
# random_state    59.0
# score           99.0
# Name: 58, dtype: float64

# %%
# n_estimators_ = int(best_params['n_estimators'])
# max_depth_ = int(best_params['max_depth'])
# random_state_ = int(best_params['random_state'])
n_estimators_ = 14
max_depth_ = 12
random_state_ = 59
from sklearn.metrics import confusion_matrix
clf4 = RandomForestClassifier(
        criterion='entropy',class_weight='balanced', 
		n_estimators=n_estimators_, # Số lượng cây trong rừng (default=100)
		max_depth=max_depth_, # Độ sâu tối đa của cây (default=None, grow until all leaves are pure)
		max_features='sqrt', # Số đặc trưng tối đa được xem xét khi tách (default='sqrt')
		bootstrap=True, # Có sử dụng bootstrap hay không (default=True)
		n_jobs=-1, # Số luồng thực thi song song (-1 để sử dụng tất cả CPU, default=None)
        # ccp_alpha=0.0005,
		random_state=random_state_
    ).fit(train_features, label_train)
print('Accuracy of RF classifier on training set: {:.1f}'
     .format(clf4.score(train_features, label_train)*100))
print('Accuracy of RF classifier on test set: {:.1f}'
     .format(clf4.score(test_features, label_test)*100))
predicted4 = clf4.predict(test_features)
confusion_test4 = confusion_matrix(label_test, predicted4)

avg_accuracy, avg_sensitivity, avg_specificity, avg_precision,_ = calculate_metrics(confusion_test4,class_names)
print(
    f"accuracy:{avg_accuracy*100:.1f}  sensitivity:{avg_sensitivity*100:.1f}  "
    f"sensitivity:{avg_specificity*100:.1f}  precision:{avg_precision*100:.1f}"
)
# # Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(5.8, 6))
sns.heatmap(confusion_test4, annot=True, fmt="d", cmap="Greens", xticklabels=class_names, yticklabels=class_names, cbar=False, annot_kws={"size": 17})

# Set labels and title with font size 14
plt.xlabel('Predicted', fontsize=17)
plt.ylabel('True', fontsize=17)
plt.title('(c) Results on SFDLA', fontsize=17)
# Rotate x-axis labels by 20 degrees
plt.xticks(rotation=30,fontsize=17)
plt.yticks(rotation=30,fontsize=17)
# Show plot
plt.show()
# Out:
# Accuracy of RF classifier on training set: 100.0
# Accuracy of RF classifier on test set: 99.0
# accuracy:99.8  sensitivity:98.0  sensitivity:99.9  precision:99.2

# %%
start_time = time.time()
clf4.fit(train_features, label_train)
train_time = time.time() - start_time

# Dự đoán
start_time = time.time()
predicted = clf4.predict(test_features)
test_time = time.time() - start_time

# Confusion matrix
confusion_test = confusion_matrix(label_test, predicted)

# Tính toán các chỉ số từ ma trận nhầm lẫn
avg_accuracy, avg_sensitivity, avg_specificity, avg_precision, _ = calculate_metrics(confusion_test4,class_names)

# AUC (cho đa lớp)
auc_score = calculate_auc_multiclass(clf4, test_features, label_test)

# Tính Accuracy trên tập kiểm tra
test_accuracy = clf4.score(test_features, label_test)* 100  # Accuracy (%)

# Tính F1-score (macro và micro) trên tập kiểm tra
test_f1_macro = f1_score(label_test, predicted, average='macro') * 100  # F1 macro (%)
test_f1_micro = f1_score(label_test, predicted, average='micro') * 100  # F1 micro (%)
results = []
# Lưu kết quả
results.append({
        'Model':'RF',
        'Train Time (seconds)': train_time,
        'Test Time (seconds)': test_time,
        'Model Size (MB)': round(model_size_in_bytes(clf4)/1024**2,3),
        'Accuracy (%)': round(avg_accuracy * 100, 1),  # Accuracy (%)
        'Sensitivity (%)': round(avg_sensitivity * 100, 1),  # Sensitivity (%)
        'Specificity (%)': round(avg_specificity * 100, 1),  # Specificity (%)
        'Precision (%)': round(avg_precision * 100, 1),  # Precision (%)
        'Test F1 Micro (%)': round(test_f1_micro, 1),
        'Test F1 Macro (%)': round(test_f1_macro, 1)
    })
# Chuyển kết quả thành DataFrame để tiện xử lý
results_model = pd.DataFrame(results).copy()

# Hiển thị kết quả
results_model
# Out:
#   Model  Train Time (seconds)  Test Time (seconds)  Model Size (MB)  \
# 0    RF              0.052767             0.011948            0.247
#
#    Accuracy (%)  Sensitivity (%)  Specificity (%)  Precision (%)  \
# 0          99.8             98.0             99.9           99.2
#
#    Test F1 Micro (%)  Test F1 Macro (%)
# 0               99.0               98.6

# %%
# K-folds
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import f1_score
X_full = np.array(list(train_features)+list(test_features))
y_full = np.array(label_train+label_test)

kf_cv = KFold(n_splits=5, shuffle=True, random_state=1)

cv_train_accuracies = []
cv_test_accuracies = []
cv_conf_matrices = []

# Để lưu fold tốt nhất
best_fold_index = -1
best_test_acc = -1
best_conf_matrix = None
best_train_acc = -1
train_feature_= []
test_feature_=[]
label_train_=[]
label_test_=[]
mode_rf = 0
resultsKfold=[]
for fold_index, (cv_train_idx, cv_test_idx) in enumerate(kf_cv.split(X_full), start=1):
    X_cv_train = X_full[cv_train_idx]
    y_cv_train = y_full[cv_train_idx]
    X_cv_test = X_full[cv_test_idx]
    y_cv_test = y_full[cv_test_idx]
    rf_cv_model = RandomForestClassifier(criterion='entropy',n_jobs=-1, n_estimators=n_estimators_,
                                max_depth=max_depth_,max_features='sqrt',class_weight='balanced', 
                                bootstrap=True, random_state=random_state_).fit(X_cv_train, y_cv_train)

    y_cv_pred = rf_cv_model.predict(X_cv_test)

    acc_cv_train = rf_cv_model.score(X_cv_train, y_cv_train)
    acc_cv_test = rf_cv_model.score(X_cv_test,y_cv_test)
    cm_cv = confusion_matrix(y_cv_test, y_cv_pred)
     # Tính toán các chỉ số từ ma trận nhầm lẫn
    avg_accuracy, avg_sensitivity, avg_specificity, avg_precision, _ = calculate_metrics(cm_cv,class_names)

    # AUC (cho đa lớp)
    auc_score = calculate_auc_multiclass(rf_cv_model, X_cv_test, y_cv_test)

    # Tính Accuracy trên tập kiểm tra
    test_accuracy = accuracy_score(y_cv_test, y_cv_pred) * 100  # Accuracy (%)

    # Tính F1-score (macro và micro) trên tập kiểm tra
    test_f1_macro = f1_score(y_cv_test, y_cv_pred, average='macro') * 100  # F1 macro (%)
    test_f1_micro = f1_score(y_cv_test, y_cv_pred, average='micro') * 100  # F1 micro (%)

    # Lưu kết quả
    resultsKfold.append({
        'Fold': fold_index,
        'Model Size (Bytes)': model_size_in_bytes(rf_cv_model),
        'Accuracy (%)': round(avg_accuracy * 100, 1),  # Accuracy (%)
        'Sensitivity (%)': round(avg_sensitivity * 100, 1),  # Sensitivity (%)
        'Specificity (%)': round(avg_specificity * 100, 1),  # Specificity (%)
        'Precision (%)': round(avg_precision * 100, 1),  # Precision (%)
        'Train F1 Micro':round(acc_cv_train*100,1),
        'Test F1 Micro (%)': round(test_f1_micro, 1),
        'Test F1 Macro (%)': round(test_f1_macro, 1),
        'AUC': round(auc_score*100, 1)  # Làm tròn AUC
    })

    # Lưu lại fold tốt nhất nếu tốt hơn fold trước đó
    if acc_cv_test > best_test_acc:
        best_fold_index = fold_index
        best_test_acc = acc_cv_test
        best_train_acc = acc_cv_train
        best_conf_matrix = cm_cv
        train_feature_= X_cv_train
        test_feature_=X_cv_test
        label_train_=y_cv_train
        label_test_=y_cv_test
        mode_rf = rf_cv_model
    # Lưu để thống kê chung
    cv_train_accuracies.append(acc_cv_train)
    cv_test_accuracies.append(acc_cv_test)
    cv_conf_matrices.append(cm_cv)

df_resultsKfold = pd.DataFrame(resultsKfold)
# Tính trung bình các cột số học, bỏ qua cột 'Model'
mean_row = df_resultsKfold.drop(columns=['Fold']).mean(numeric_only=True)
mean_row = mean_row.round(1)
# Chuyển thành dict và thêm cột 'Model' là 'Average'
mean_row_dict = {'Fold': 'Average'}
mean_row_dict.update(mean_row.to_dict())

# Thêm vào cuối danh sách kết quả
resultsKfold.append(mean_row_dict)
df_resultsKfold = pd.DataFrame(resultsKfold)
df_resultsKfold
# Out:
#       Fold  Model Size (Bytes)  Accuracy (%)  Sensitivity (%)  \
# 0        1            302826.0          99.8             98.0
# 1        2            302186.0          99.8             97.9
# 2        3            295786.0          99.7             95.4
# 3        4            299626.0          99.7             96.8
# 4        5            294186.0          99.8             97.2
# 5  Average            298922.0          99.8             97.1
#
#    Specificity (%)  Precision (%)  Train F1 Micro  Test F1 Micro (%)  \
# 0             99.9           97.3           100.0               98.5
# 1             99.9           98.2           100.0               98.5
# 2             99.8           98.2           100.0               98.3
# 3             99.8           97.6           100.0               98.3
# 4             99.9           98.9            99.8               98.9
# 5             99.9           98.0           100.0               98.5
#
#    Test F1 Macro (%)    AUC
# ...

# %%
import time
import pickle
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, f1_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
import xgboost as xgb
import lightgbm as lgb
import warnings
warnings.filterwarnings("ignore")



# Gán lại để dễ dùng
data_full = np.array(list(train_features) + list(test_features))
label_full = np.array(label_train + label_test)

# KFold
kf_cv = KFold(n_splits=5, shuffle=True, random_state=1)

# Các mô hình (không thay đổi tham số)
models = [
    ('RF', RandomForestClassifier(criterion='entropy',n_jobs=-1, n_estimators=n_estimators_,
                                max_depth=max_depth_,max_features='sqrt',class_weight='balanced', 
                                bootstrap=True, random_state=random_state_)),
    ('XGBoost', xgb.XGBClassifier(n_estimators=n_estimators_, max_depth=12, learning_rate=0.05, random_state=random_state_)),
    ('DT', DecisionTreeClassifier(max_depth=18)),
    ('GBDT', GradientBoostingClassifier(learning_rate=0.05, n_estimators=18, max_depth=12, random_state=random_state_)),
    ('SVM', SVC(C=27, kernel='linear', random_state=random_state_, probability=False)),
    ('LightGBM', lgb.LGBMClassifier(n_estimators=18, max_depth=12, learning_rate=0.05, random_state=random_state_, verbose=-1))
]

final_results = []
total_model = {}
for model_name, model_ in models:
    nameModel,size_model,acc_list, sens_list, spec_list, prec_list = [],[], [], [], [],[]
    train_f1_micro_list, test_f1_micro_list, test_f1_macro_list, auc_list = [], [], [], []
    
    for train_index, test_index in kf_cv.split(data_full):
        fold_train, fold_test = data_full[train_index], data_full[test_index]
        label_fold_train, label_fold_test = label_full[train_index], label_full[test_index]
        
        model_.fit(fold_train, label_fold_train)
        y_pred = model_.predict(fold_test)
        
        cm = confusion_matrix(label_fold_test, y_pred)
        avg_accuracy, avg_sensitivity, avg_specificity, avg_precision, _ = calculate_metrics(cm, class_names)

        # F1 and AUC
        nameModel.append(model_name)
        size_model.append(model_size_in_bytes(model_))
        f1_micro_train = round(f1_score(label_fold_train, model_.predict(fold_train), average='micro') * 100, 1)
        f1_micro_test = round(f1_score(label_fold_test, y_pred, average='micro') * 100, 1)
        f1_macro_test = round(f1_score(label_fold_test, y_pred, average='macro') * 100, 1)
        avg_accuracy = round(avg_accuracy * 100, 1)
        avg_sensitivity = round(avg_sensitivity * 100, 1)
        avg_specificity = round(avg_specificity * 100, 1)
        avg_precision = round(avg_precision * 100, 1)
        acc_list.append(avg_accuracy)
        sens_list.append(avg_sensitivity)
        spec_list.append(avg_specificity)
        prec_list.append(avg_precision)
        train_f1_micro_list.append(f1_micro_train)
        test_f1_micro_list.append(f1_micro_test)
        test_f1_macro_list.append(f1_macro_test)
    # Sau khi tính xong các metrics từng fold
    final_results.append({
        'Model': model_name,
        'Model Size (Bytes)': round(np.mean(size_model), 1),
        'Accuracy (%)': round(np.mean(acc_list), 1),
        'Sensitivity (%)': round(np.mean(sens_list), 1),
        'Specificity (%)': round(np.mean(spec_list), 1),
        'Precision (%)': round(np.mean(prec_list), 1),
        'Train F1 Micro (%)': round(np.mean(train_f1_micro_list), 1),
        'Test F1 Micro (%)': round(np.mean(test_f1_micro_list), 1),
        'Test F1 Macro (%)': round(np.mean(test_f1_macro_list), 1),
    })
    total_model[model_name] = {
        'Model': nameModel.copy(),
        'Model Size (Bytes)': size_model.copy(),
        'Accuracy (%)': acc_list.copy(),
        'Sensitivity (%)': sens_list.copy(),
        'Specificity (%)': spec_list.copy(),
        'Precision (%)': prec_list.copy(),
        'Train F1 Micro (%)': train_f1_micro_list.copy(),
        'Test F1 Micro (%)': test_f1_micro_list.copy(),
        'Test F1 Macro (%)': test_f1_macro_list.copy()
    }

# Xuất kết quả
results_model = pd.DataFrame(final_results)
results_model
# Out:
#       Model  Model Size (Bytes)  Accuracy (%)  Sensitivity (%)  \
# 0        RF            298922.0          99.8             97.1
# 1   XGBoost            212719.4          99.5             95.0
# 2        DT             17527.0          99.4             93.3
# 3      GBDT           5671052.0          99.0             88.7
# 4       SVM             97194.6          99.7             97.1
# 5  LightGBM            736431.2          99.6             94.6
#
#    Specificity (%)  Precision (%)  Train F1 Micro (%)  Test F1 Micro (%)  \
# 0             99.9           98.0               100.0               98.5
# 1             99.8           95.3                99.7               97.3
# 2             99.7           93.6               100.0               96.2
# 3             99.3           95.3               100.0               94.0
# 4             99.9           95.9                99.9               98.3
# 5             99.7           97.7                99.6               97.5
#
# ...

# %%
# try:
# # # Ghi kết quả vào file CSV
#       joblib.dump(data_train, save_+'data_train.pkl')
#       joblib.dump(data_test, save_+'data_test.pkl')
#       joblib.dump(train_features, save_+'SFDLA_train_features.pkl')
#       joblib.dump(test_features, save_+'SFDLA_test_features.pkl')
#       joblib.dump(label_test, save_+'SFDLA_label_test.pkl')
#       joblib.dump(label_train, save_+'SFDLA_label_train.pkl')
#       joblib.dump(clf4, save_+'clf4.pkl')
#       joblib.dump(best_params, save_+'best_params.pkl')
#       joblib.dump(total_model, save_+'total_model.pkl')
#       joblib.dump(df_resultsKfold, save_+'df_resultsKfold.pkl')
#       results_df.to_csv(save_+"search_results_SLFDA.csv", index=False)
#       print("Kết quả đã được ghi thành công vào file CSV.")
# except Exception as e:
#     print(f"Không thể ghi file CSV. Lỗi: {e}")
# Out:
# Kết quả đã được ghi thành công vào file CSV.
