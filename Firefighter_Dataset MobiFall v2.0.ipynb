# %%
# Dataset MobiFall v2.0

'''
Hàng 1: #Acceleration force along the x y z axes (including gravity).
Hàng 2: #timestamp(ns),x,y,z(m/s^2)
Hàng 3: #Datetime: 05/07/2013 11:27:39
Hàng 4: ##########################################
Hàng 5: #Activity: 12 - BSC - Back sitting chair - 10s
Hàng 6: #Subject ID: 1
Hàng 7: #First Name: sub1
Hàng 8: #Last Name: sub1
Hàng 9: #Age: 32
Hàng 10: #Height(cm): 180
Hàng 11: #Weight(kg): 85
Hàng 12: #Gender: Male
Hàng 13: ##########################################
Hàng 14:
Hàng 15:
Hàng 16: @DATA
Hàng 17: 2318482693000, 0.89064306, -9.576807, -0.019153614
Hàng 18: 2318492108000, 0.91937345, -9.595961, -0.05746084
Hàng 19: ...
'''

'''
Subjects:
+----+-------+---------+-----+--------+--------+--------+
| id | Name  | Surname | Age | Height | Weight | Gender |
+----+-------+---------+-----+--------+--------+--------+
| 1  | pat1  | pat1    | 32  | 180    | 85     | M      |
| 2  | pat2  | pat2    | 26  | 169    | 64     | M      |
| 3  | pat3  | pat3    | 26  | 164    | 55     | F      |   # not considered (3)
| 4  | pat4  | pat4    | 32  | 186    | 93     | M      |
| 5  | pat5  | pat5    | 36  | 160    | 50     | F      |   # not considered (5)
| 6  | pat6  | pat6    | 22  | 172    | 62     | F      |   # not considered (6)
| 7  | pat7  | pat7    | 25  | 189    | 80     | M      |
| 8  | pat8  | pat8    | 22  | 183    | 93     | M      |
| 9  | pat9  | pat9    | 30  | 177    | 102    | M      |
| 10 | pat10 | pat10   | 26  | 170    | 90     | F      |   # not considered (10)
| 11 | Pat11 | pat11   | 26  | 168    | 80     | F      |   # not considered (11)
| 12 | sub12 | sub12   | 29  | 178    | 83     | M      |
| 13 | sub13 | sub13   | 24  | 177    | 62     | M      |
| 14 | sub14 | sub14   | 24  | 178    | 85     | M      |
| 15 | sub15 | sub15   | 25  | 173    | 82     | M      |
| 16 | sub16 | sub16   | 27  | 172    | 56     | F      |   # not considered (16)
| 17 | sub17 | sub17   | 25  | 173    | 67     | M      |
| 18 | sub18 | sub18   | 25  | 176    | 73     | M      |
| 19 | sub19 | sub19   | 25  | 161    | 63     | F      |   # not considered (19)
| 20 | sub20 | sub20   | 26  | 178    | 71     | M      |
| 21 | sub21 | sub21   | 25  | 180    | 70     | M      |
| 29 | sub29 | sub29   | 27  | 186    | 103    | M      |
| 30 | sub30 | sub30   | 47  | 172    | 90     | M      |
| 31 | sub31 | sub31   | 27  | 170    | 75     | M      |
+----+-------+---------+-----+--------+--------+--------+
'''

'''
Activities of Daily Living:
+----+------+--------------+--------+----------+--------------------------------+
| id | Code | Activity     | Trials | Duration | Description                    |
+----+------+--------------+--------+----------+--------------------------------+
| 1  | STD  | Standing     | 1      | 5m       | Standing with subtle movements | # Đứng với các chuyển động tinh tế    - (Hành động lặp lại)
| 2  | WAL  | Walking      | 1      | 5m       | Normal walking                 | # Đi bộ bình thường                   - (Hành động lặp lại)
| 3  | JOG  | Jogging      | 3      | 30s      | Jogging                        | # Chạy bộ                             - (Hành động lặp lại)
| 4  | JUM  | Jumping      | 3      | 30s      | Continuous jumping             | # Nhảy liên tục                       - (Hành động lặp lại)
| 5  | STU  | Stairs up    | 6      | 10s      | Stairs up (10 stairs)          | # Lên cầu thang                       - (Hành động lặp lại)
| 6  | STN  | Stairs down  | 6      | 10s      | Stairs down (10 stairs)        | # Xuống cầu thang                     - (Hành động lặp lại)
| 7  | SCH  | Sit chair    | 6      | 6s       | Sitting on a chair             | # Ngồi trên ghế                       - (Hành động không lặp lại)         - (not considered)
| 8  | CSI  | Car-step in  | 6      | 6s       | Step in a car                  | # Bước vào xe                         - (Hành động không lặp lại)         - (not considered)
| 9  | CSO  | Car-step out | 6      | 6s       | Step out a car                 | # Bước ra xe                          - (Hành động không lặp lại)         - (not considered)
+----+------+--------------+--------+----------+--------------------------------+


Falls:
+----+------+--------------------+--------+----------+---------------------------------------------------------+
| id | Code | Activity           | Trials | Duration | Description                                             |
+----+------+--------------------+--------+----------+---------------------------------------------------------+
| 10 | FOL  | Forward-lying      | 3      | 10s      | Fall Forward from standing, use of hands to dampen fall | # Ngã về phía trước từ tư thế đứng, dùng tay để giảm lực ngã
| 11 | FKL  | Front-knees-lying  | 3      | 10s      | Fall forward from standing, first impact on knees       | # Ngã về phía trước từ tư thế đứng, lần đầu tiên va chạm vào đầu gối
| 12 | BSC  | Back-sitting-chair | 3      | 10s      | Fall backward while trying to sit on a chair            | # Ngã về phía sau khi cố ngồi trên ghế     - (not considered)
| 13 | SDL  | Sideward-lying     | 3      | 10s      | Fall sidewards from standing, bending legs              | # Ngã sang một bên khi đang đứng, chân cong
+----+------+--------------------+--------+----------+---------------------------------------------------------+
'''
# Out:
# '\nActivities of Daily Living:\n+----+------+--------------+--------+----------+--------------------------------+\n| id | Code | Activity     | Trials | Duration | Description                    |\n+----+------+--------------+--------+----------+--------------------------------+\n| 1  | STD  | Standing     | 1      | 5m       | Standing with subtle movements | # Đứng với các chuyển động tinh tế    - (Hành động lặp lại)\n| 2  | WAL  | Walking      | 1      | 5m       | Normal walking                 | # Đi bộ bình thường                   - (Hành động lặp lại)\n| 3  | JOG  | Jogging      | 3      | 30s      | Jogging                        | # Chạy bộ                             - (Hành động lặp lại)\n| 4  | JUM  | Jumping      | 3      | 30s      | Continuous jumping             | # Nhảy liên tục                       - (Hành động lặp lại)\n| 5  | STU  | Stairs up    | 6      | 10s      | Stairs up (10 stairs)          | # Lên cầu thang                       - (Hành động lặp lại)\n| 
# ...

# %%
import os
import pandas as pd
import time
import pickle
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, roc_auc_score, f1_score
import xgboost as xgb
import lightgbm as lgb
# Thư mục gốc chứa dữ liệu
possible_dirs = [
    'D:/NCSHieuServer/My Drive/NCSHieu/linh cuu hoa/code python/MobiFall'
]

# Tìm đường dẫn tồn tại đầu tiên
root_dir = next((d for d in possible_dirs if os.path.exists(d)), None)

# Hàm kiểm tra và xử lý từng tệp dữ liệu
def check_file(file_path):
    try:
        # Đọc tệp dữ liệu, bỏ qua metadata ở trên đầu và chỉ đọc dữ liệu bắt đầu từ dòng @DATA (dòng 17)
        with open(file_path, 'r') as f:
            lines = f.readlines()
        
        # Tìm dòng bắt đầu dữ liệu (sau dòng @DATA, tức là dòng 17)
        data_start_index = lines.index('@DATA\n') + 1  # Dòng dữ liệu bắt đầu ngay sau '@DATA'
        data_lines = lines[data_start_index:]  # Dữ liệu thực tế từ dòng 17 trở đi
        
        # Đọc dữ liệu vào dataframe
        data = pd.DataFrame([line.strip().split(',') for line in data_lines], columns=["Timestamp", "Acc_X", "Acc_Y", "Acc_Z"])
        
        # Kiểm tra dữ liệu trong các cột X, Y, Z
        for col in ['Acc_X', 'Acc_Y', 'Acc_Z']:
            # Chuyển cột sang kiểu float và kiểm tra nếu có giá trị không hợp lệ
            data[col] = pd.to_numeric(data[col], errors='coerce')
            # Kiểm tra nếu có giá trị NaN trong cột
            if data[col].isnull().any():
                raise ValueError(f"Cột {col} có giá trị NaN hoặc không hợp lệ")
                
    except Exception as e:
        # Nếu có lỗi, in ra tên tệp và thông báo lỗi
        print(f"Lỗi trong tệp: {file_path}")
        print(f"Thông báo lỗi: {str(e)}")

# Hàm kiểm tra tất cả các tệp trong thư mục
def check_all_files(root_dir):
    if os.path.exists(root_dir):
        for subdir, dirs, files in os.walk(root_dir):
            for filename in files:
                if "_acc_" in filename and filename.endswith(".txt"):
                    file_path = os.path.join(subdir, filename)
                    check_file(file_path)  # Kiểm tra tệp
    else:
        print(f"Thư mục {root_dir} không tồn tại!")

# Kiểm tra tất cả các tệp trong thư mục
check_all_files(root_dir)

# %%
import os
import pandas as pd

# Các hoạt động ngã
fall_activities = {"FOL", "FKL", "SDL"}

# Hàm kiểm tra dữ liệu trong tệp ngã
def check_fall_file(file_path):
    try:
        # Đọc dữ liệu từ tệp, bỏ qua các dòng header
        data = pd.read_csv(file_path, sep=',', header=None, names=["Timestamp", "Acc_X", "Acc_Y", "Acc_Z"], skiprows=16)
        
        # Kiểm tra từng dòng dữ liệu
        for idx, row in data.iterrows():
            if row.isnull().any():  # Kiểm tra giá trị NaN
                print(f"File lỗi: {file_path} - Dòng {idx + 17}: Giá trị NaN")
                return False
            try:
                # Kiểm tra giá trị số
                float(row["Acc_X"])
                float(row["Acc_Y"])
                float(row["Acc_Z"])
            except ValueError:
                print(f"File lỗi: {file_path} - Dòng {idx + 17}: Giá trị không phải số")
                return False
        return True  # Không có lỗi
    except Exception as e:
        print(f"File lỗi: {file_path} - Không đọc được tệp ({e})")
        return False

# Duyệt qua các tệp dữ liệu ngã
def check_fall_data_files():
    for subdir, dirs, files in os.walk(root_dir):
        for filename in files:
            if "_acc_" in filename and filename[:3] in fall_activities and filename.endswith(".txt"):
                file_path = os.path.join(subdir, filename)
                check_fall_file(file_path)

# Chạy kiểm tra
check_fall_data_files()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Đường dẫn đến tệp dữ liệu
file_path = root_dir+'/sub1/FALLS/BSC/BSC_acc_1_1.txt'

# Hàm để đọc tệp và trích xuất dữ liệu
def read_acceleration_data(file_path):
    # Đọc tệp dữ liệu
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # Tìm dòng bắt đầu dữ liệu
    data_start_index = None
    for i, line in enumerate(lines):
        if line.startswith('@DATA'):
            data_start_index = i + 1  # Dữ liệu bắt đầu ngay sau dòng @DATA
            break

    # Đọc dữ liệu gia tốc từ dòng tiếp theo
    if data_start_index is not None:
        # Đọc dữ liệu gia tốc (timestamp, x, y, z)
        data = []
        for line in lines[data_start_index:]:
            if line.strip():  # Bỏ qua các dòng rỗng
                parts = line.split(',')
                timestamp = int(parts[0]) / 1e9  # Chuyển đổi timestamp từ ns thành giây
                x = float(parts[1])
                y = float(parts[2])
                z = float(parts[3])
                data.append([timestamp, x, y, z])
        
        # Chuyển dữ liệu thành DataFrame của pandas
        df = pd.DataFrame(data, columns=["Timestamp", "Acc_X", "Acc_Y", "Acc_Z"])
        return df
    else:
        print("Không tìm thấy dữ liệu.")
        return None

# Đọc dữ liệu gia tốc từ tệp
acceleration_data = read_acceleration_data(file_path)

# Kiểm tra dữ liệu đã đọc
if acceleration_data is not None:
    # Tạo trục X là số lượng mẫu (index)
    sample_count = range(len(acceleration_data))
    
    # Vẽ đồ thị gia tốc theo trục X (sample count) và các trục Y (X, Y, Z)
    plt.figure(figsize=(10, 6))
    plt.plot(sample_count, acceleration_data['Acc_X'], label='X', color='r')
    plt.plot(sample_count, acceleration_data['Acc_Y'], label='Y', color='g')
    plt.plot(sample_count, acceleration_data['Acc_Z'], label='Z', color='b')
    
    plt.title('Accelerometer Data (ax, ay, az)')
    plt.xlabel('Sample Count')
    plt.ylabel('Acceleration (m/s²)')
    plt.legend()
    plt.grid(True)
    plt.show()
else:
    print("Không thể vẽ đồ thị do không có dữ liệu.")

print(acceleration_data.head())
print(acceleration_data.shape)  # Số dòng và cột
# Out:
#      Timestamp     Acc_X     Acc_Y     Acc_Z
# 0  2318.482693  0.890643 -9.576807 -0.019154
# 1  2318.492108  0.919373 -9.595961 -0.057461
# 2  2318.503365  0.871489 -9.595961 -0.057461
# 3  2318.512831  0.852336 -9.643845 -0.038307
# 4  2318.523222  0.871489 -9.634268 -0.057461
# (863, 4)

# %%
# %matplotlib inline
import time
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from scipy import stats, signal
import matplotlib.cm as cm
from matplotlib.colors import ListedColormap, BoundaryNorm
import matplotlib.patches as mpatches
from scipy.signal import find_peaks, savgol_filter
from scipy.stats import entropy, skew, kurtosis
from scipy.signal import welch
from numpy import cov
import matplotlib.colors as mcolors
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.ar_model import AutoReg
from IPython.core.interactiveshell import InteractiveShell
# from plotly.graph_objs import go
from plotly.subplots import make_subplots
import plotly.io as pio
import plotly.offline as pyo
import json
import warnings
import math
import scipy as sp
import scipy.fftpack
import os
# Lấy thư mục làm việc hiện tại trong Jupyter Notebook
current_file_directory = os.getcwd()

# Chuyển thư mục làm việc
os.chdir(current_file_directory)
import tkinter as tk
from tkinter import messagebox
import pickle
import easygui
import joblib
import sys
import xgboost as xgb
import lightgbm as lgb

# Hàm tính toán Accuracy, Sensitivity, Specificity và F1-Score cho mỗi ma trận nhầm lẫn
def calculate_metrics(conf_matrix, class_labels):
    # Tính toán TP, FP, FN, TN
    TP = np.diag(conf_matrix)
    FP = np.sum(conf_matrix, axis=0) - TP
    FN = np.sum(conf_matrix, axis=1) - TP
    TN = np.sum(conf_matrix) - (TP + FP + FN)

    # Tính Accuracy, Sensitivity, Specificity cho từng lớp
    accuracy = (TP + TN) / (TP + FP + TN + FN)
    sensitivity = TP / (TP + FN)
    specificity = TN / (TN + FP)
    precision = TP / (TP + FP)
    f1 = 2 * (precision * sensitivity) / (precision + sensitivity)

    metrics = []
    for i in range(len(conf_matrix)):
        metrics.append({
            'Activity': class_labels[i],
            'Acc': round(accuracy[i] * 100, 1),
            'Sen': round(sensitivity[i] * 100, 1),
            'Spe': round(specificity[i] * 100, 1),
            'Pre': round(precision[i] * 100, 1),
            'F1': round(f1[i] * 100, 1)
        })

    # Tạo y_true và y_pred từ ma trận nhầm lẫn để tính f1_micro
    y_true_all = []
    y_pred_all = []
    for i in range(len(conf_matrix)):
        for j in range(len(conf_matrix)):
            count = conf_matrix[i, j]
            y_true_all += [i] * count
            y_pred_all += [j] * count

    f1_micro = f1_score(y_true_all, y_pred_all, average='micro', zero_division=0)

    # Tính trung bình các chỉ số (bỏ qua NaN)
    avg_accuracy = np.nanmean(accuracy)
    avg_sensitivity = np.nanmean(sensitivity)
    avg_specificity = np.nanmean(specificity)
    avg_precision = np.nanmean(precision)
    return avg_accuracy, avg_sensitivity, avg_specificity, avg_precision, f1_micro

def model_size_in_bytes(model):
    return len(pickle.dumps(model))

def calculate_auc_multiclass(model, test_features, label_test):
    try:
        predicted_probs = model.predict_proba(test_features)
        return roc_auc_score(label_test, predicted_probs, multi_class='ovr')
    except:
        return None

def featuresFromBufferNew(at):
    feat = np.zeros(48)   
    ax = np.array(at['Acc_X'], dtype=np.float64)
    ay = np.array(at['Acc_Y'], dtype=np.float64)
    az = np.array(at['Acc_Z'], dtype=np.float64)
    mag = np.sqrt(ax**2+ay**2+az**2)-1
    # Mean
    mean_acc = [np.mean(i) for i in [ax, ay, az]]
    feat[0:3] = mean_acc

    # Energy
    energy_acc = [np.sqrt(np.mean(i**2)) for i in [ax, ay, az]]
    feat[3:6] = energy_acc

    # Standard Deviation (std)
    std_acc = [np.std(i) for i in [ax, ay, az]]
    feat[6:9] = std_acc

    # Maximum
    max_ = [np.max(i) for i in [ax, ay, az]]
    feat[9:12] = max_

    # Range
    Range_acc = [np.amax(i) - np.amin(i) for i in [ax, ay, az]]
    feat[12:15] = Range_acc

    # Mean Absolute Deviation
    mad_acc = [np.mean(np.abs(i - np.mean(i))) for i in [ax, ay, az]]
    feat[15:18] = mad_acc

    # Skewness
    skewness_acc = [skew(i) for i in [ax, ay, az]]
    feat[18:21] = skewness_acc

    # Kurtosis
    kurtosis_acc = [kurtosis(i) for i in [ax, ay, az]]
    feat[21:24] = kurtosis_acc

    # Interquartile Range
    iqr_val = [np.percentile(i, 75) - np.percentile(i, 25) for i in [ax, ay, az]]
    feat[24:27] = iqr_val

    # Signal Magnitude Area (SMA)
    sma_acc = [np.sum(np.abs(i)) for i in [ax, ay, az]]
    feat[27:30] = sma_acc

    # Simple Square Integral
    ssi_acc = [np.sum(i**2) for i in [ax, ay, az]]
    feat[30:33] = ssi_acc

    # Median Absolute Deviation
    median_mad_acc = [np.median(np.abs(i - np.median(i))) for i in [ax, ay, az]]
    feat[33:36] = median_mad_acc
    
    # Hjorth Mobility
    hjorth_mobility_acc = [np.sqrt(np.var(np.diff(i)) / np.var(i)) for i in [ax, ay, az]]
    feat[36:39] = hjorth_mobility_acc  # Vị trí lưu Hjorth Mobility

    # Hjorth Complexity
    hjorth_complexity_acc = [
        (np.sqrt(np.var(np.diff(np.diff(i))) / np.var(np.diff(i))) /
        np.sqrt(np.var(np.diff(i)) / np.var(i)))
        for i in [ax, ay, az]
    ]
    feat[39:42] = hjorth_complexity_acc  # Vị trí lưu Hjorth Complexity
    
    #  (lag=1)
    autocorr_acc = [acf(i, nlags=1)[1] for i in [ax, ay, az]]
    feat[42:45] = autocorr_acc  # Vị trí lưu Autocorrelation
    
    #Average Amplitude Change
    avg_amp_change = [np.mean(np.abs(np.diff(i))) for i in [ax, ay, az]]
    feat[45:48] = avg_amp_change  # Vị trí lưu Average Amplitude Change
    return feat

# Hàm tính kích thước mô hình
def model_size_in_bytes(model):
    return len(pickle.dumps(model))

def filter_acc_axes(data, fs=25, std_threshold=0.2):
    """
    Lọc dữ liệu gia tốc 3 trục 'Acc_X', 'Acc_Y', 'Acc_Z' bằng cách loại bỏ các phân đoạn 1 giây 
    có độ lệch chuẩn của S_a nhỏ hơn ngưỡng (0.2).

    Tham số:
        - data: DataFrame chứa các cột 'Acc_X', 'Acc_Y', 'Acc_Z'.
        - fs: Tần số lấy mẫu (Hz), mặc định 25 Hz.
        - std_threshold: Ngưỡng độ lệch chuẩn, mặc định 0.2.

    Trả về:
        - filtered_data: DataFrame chứa tín hiệu 3 trục đã được lọc.
        - indices: Các chỉ số được giữ lại.
    """
    # Trích xuất các trục gia tốc từ DataFrame
    a_x = data['Acc_X'].to_numpy()
    a_y = data['Acc_Y'].to_numpy()
    a_z = data['Acc_Z'].to_numpy()

    # Tính S_a (độ lệch tổng hợp)
    S_a = np.sqrt((a_x - np.mean(a_x))**2 + (a_y - np.mean(a_y))**2 + (a_z - np.mean(a_z))**2)

    # Kích thước cửa sổ (1 giây tương ứng với fs mẫu)
    window_size = fs
    num_segments = len(S_a) // window_size

    # Lọc tín hiệu 3 trục
    filtered_indices = []  # Lưu các chỉ số giữ lại
    for i in range(num_segments):
        start_idx = i * window_size
        end_idx = start_idx + window_size
        segment = S_a[start_idx:end_idx]

        # Kiểm tra độ lệch chuẩn của phân đoạn
        if np.std(segment) >= std_threshold:
            filtered_indices.extend(range(start_idx, end_idx))

    # Tạo DataFrame mới chứa các tín hiệu đã được giữ lại
    filtered_data = data.iloc[filtered_indices].reset_index(drop=True)
    return filtered_data, S_a

def handle_nan_rows(data):
    """
    Quét DataFrame tìm các giá trị NaN:
    - Nếu hàng xuất hiện NaN, thay thế bằng trung bình cộng của hàng liền kề trước và sau (tính trên từng cột chứa NaN).
    - Nếu hàng đầu tiên hoặc hàng cuối cùng chứa NaN, xóa hàng đó đi.
    - Nếu có 2 hàng liên tiếp chứa NaN ở cùng một cột, xóa cả hai hàng đó.
    - Nếu các hàng chứa NaN ở các cột khác nhau, xử lý từng cột riêng biệt.
    - Hiển thị thông tin các hàng có 2 hàng liên tiếp chứa NaN ở cùng một cột.

    Parameters:
    - data (pd.DataFrame): DataFrame cần xử lý.

    Returns:
    - pd.DataFrame: DataFrame đã xử lý.
    """
    error_=0
    # Tạo bản sao của DataFrame để không làm thay đổi dữ liệu gốc
    data = data.copy()

    # Lặp lại quá trình xử lý cho đến khi không còn NaN
    while data.isna().any().any():
        indexes_to_drop = []  # Lưu danh sách các hàng cần xóa

        for index in range(len(data)):
            if data.iloc[index].isna().any():  # Kiểm tra hàng có giá trị NaN
                if index == 0 or index == len(data) - 1:  # Nếu là hàng đầu tiên hoặc hàng cuối cùng
                    indexes_to_drop.append(index)
                elif index < len(data) - 1 and data.iloc[index].isna().any() and data.iloc[index + 1].isna().any():
                    # Nếu có 2 hàng liên tiếp chứa NaN ở cùng cột
                    nan_columns = data.iloc[index].isna() & data.iloc[index + 1].isna()
                    if nan_columns.any():
                        print(f"Hai hàng liên tiếp chứa NaN ở cùng cột: hàng {index} và hàng {index + 1}, cột: {list(data.columns[nan_columns])}")
                        indexes_to_drop.extend([index, index + 1])
                        error_=1
                    else:
                        # Xử lý bình thường nếu NaN ở các cột khác nhau
                        for col in data.columns:
                            if pd.isna(data.iloc[index][col]):
                                data.at[index, col] = (data.iloc[index - 1][col] + data.iloc[index + 1][col]) / 2
                else:
                    # Xử lý bình thường (từng cột riêng biệt)
                    for col in data.columns:
                        if pd.isna(data.iloc[index][col]):
                            data.at[index, col] = (data.iloc[index - 1][col] + data.iloc[index + 1][col]) / 2

        data.drop(index=indexes_to_drop, inplace=True)

        # Reset lại chỉ số sau khi xóa hàng
        data.reset_index(drop=True, inplace=True)

    return data,error_

# %%
import os
import pandas as pd

# Thư mục gốc chứa dữ liệu

# Loại bỏ các thư mục nữ
excluded_subjects = {'sub3', 'sub5', 'sub6', 'sub10', 'sub11', 'sub16', 'sub19'}

# Loại bỏ các hoạt động không được xem xét
excluded_activities = {'BSC', 'CSI', 'CSO'}#ngã từ ghế, ngồi xuống ghế, vào/ra ô tô
target_names = [
    'ST', # 0
    'WA', # 1
    'JO', # 2
    'JU', # 3
    'US', # 4
    'DS', # 5
    'FA', # 6
    'SI'#7
]
# Cấu hình thông số cửa sổ
window_size = 3* 100  # 6 giây * 100Hz = 600 mẫu
stride = 3*100   # Độ chồng 0% (300 mẫu)

# Hàm xử lý các tệp dữ liệu cho hoạt động lặp lại
def process_repeated_activity(file_path):
    w_activity = []
    data = pd.read_csv(file_path, sep=',', header=None, names=["Timestamp", "Acc_X", "Acc_Y", "Acc_Z"], skiprows=16)[['Acc_X','Acc_Y','Acc_Z']]/9.80665
    w_activity = [data[i:i+window_size].reset_index(drop=True) for i in range(0, int(len(data)), stride) if i+window_size<=int(len(data))]
    return w_activity

# Hàm xử lý các tệp dữ liệu cho hoạt động không lặp lại
def process_non_repeated_activity(file_path):
    data = pd.read_csv(file_path, sep=',', header=None, names=["Timestamp", "Acc_X", "Acc_Y", "Acc_Z"], skiprows=16)[['Acc_X','Acc_Y','Acc_Z']]/9.80665
    return data  # Một tệp là một cửa sổ

# Hàm xử lý các tệp theo mã hoạt động
def process_activity_files(activity_code, activity_name):
    windows = []
    for subdir, dirs, files in os.walk(root_dir):
        # Bỏ qua các thư mục không hợp lệ (nữ)
        subdir_name = os.path.basename(subdir)
        if subdir_name in excluded_subjects:
            continue
        for filename in files:
            # Loại bỏ các hoạt động không được xem xét
            if "_acc_" in filename and filename.startswith(activity_code) and filename.endswith(".txt"):
                file_path = os.path.join(subdir, filename)
                if activity_code in excluded_activities:
                    continue  # Bỏ qua các hoạt động bị loại trừ
                if activity_code in {"STD", "WAL", "JOG", "JUM", "STU", "STN"}:  # Lặp lại
                    windows = windows + process_repeated_activity(file_path)
                elif activity_code in {"FOL", "FKL", "SDL"}:
                    windows = windows + [process_non_repeated_activity(file_path)[0:600]]    
                else:  # Không lặp lại
                    windows = windows + [process_non_repeated_activity(file_path)[0:window_size]]
    print(f"{activity_name} =", len(windows))
    return windows
def extract_peak_segment_with_noise_padding(df):
    acc_mag = np.sqrt(df['Acc_X']**2 + df['Acc_Y']**2 + df['Acc_Z']**2)
    peak_idx = acc_mag.idxmax()

    left_size = 150*2
    right_size = 149*2

    start_idx = peak_idx - left_size
    end_idx = peak_idx + right_size + 1

    left_part = df.iloc[max(0, start_idx):peak_idx]
    peak_row = df.iloc[[peak_idx]]
    right_part = df.iloc[peak_idx + 1:min(len(df), end_idx)]

    def generate_noisy_samples(ref_df, num_samples):
        mean = ref_df.mean(numeric_only=True)
        numeric_cols = mean.index
        noise = np.random.uniform(-0.05, 0.05, size=(num_samples, len(numeric_cols)))
        samples = mean.values + noise
        gen_df = pd.DataFrame(samples, columns=numeric_cols)

        # Xử lý cột không phải số (vd: timestamp)
        for col in df.columns:
            if col not in numeric_cols:
                gen_df[col] = np.nan
        return gen_df[df.columns]

    # Padding trái
    if len(left_part) < left_size:
        pad_count = left_size - len(left_part)
        pad_data = generate_noisy_samples(df.iloc[:20], pad_count)
        left_part = pd.concat([pad_data, left_part], ignore_index=True)

    # Padding phải
    if len(right_part) < right_size:
        pad_count = right_size - len(right_part)
        pad_data = generate_noisy_samples(df.iloc[-20:], pad_count)
        right_part = pd.concat([right_part, pad_data], ignore_index=True)

    segment = pd.concat([left_part, peak_row, right_part], ignore_index=True)

    return segment
# Tạo danh sách dữ liệu cho từng hoạt động
w_Standing = process_activity_files("STD", 'Standing')
w_Walking = process_activity_files("WAL", 'Walking')
w_Jogging = process_activity_files("JOG", 'Jogging')
w_Jumping = process_activity_files("JUM", 'Jumping')
w_StairsUp = process_activity_files("STU", 'Stairs up')
w_StairsDown = process_activity_files("STN", 'Stairs down')
w_ForwardLying = process_activity_files("FOL", 'Forward-lying')
w_FrontKneesLying = process_activity_files("FKL", 'Front-knees-lying')
w_SidewardLying = process_activity_files("SDL", 'Sideward-lying')
w_Sitting = process_activity_files("SCH", 'Sit chair')

# Tổng số cửa sổ ADLs
total_windows_adls = (len(w_Standing) + len(w_Walking) + len(w_Jogging) + len(w_Jumping) + len(w_StairsUp) + len(w_StairsDown) + len(w_Sitting))
print("\nTotal windows ADLs =", total_windows_adls)

# Tổng số cửa sổ Fall
total_windows_fall = (len(w_ForwardLying) + len(w_FrontKneesLying) + len(w_SidewardLying))
print("\nTotal windows Fall =", total_windows_fall)

# Tổng số cửa sổ
total_windows_all = (len(w_Standing) + len(w_Walking) + len(w_Jogging) + len(w_Jumping) + len(w_StairsUp) + len(w_StairsDown) + 
                    len(w_ForwardLying) + len(w_FrontKneesLying) + len(w_SidewardLying) + len(w_Sitting))
print("\nTotal windows=", total_windows_all)
# Out:
# Standing = 818
# Walking = 811
# Jogging = 223
# Jumping = 222
# Stairs up = 111
# Stairs down = 117
# Forward-lying = 72
# Front-knees-lying = 72
# Sideward-lying = 72
# Sit chair = 54
#
# Total windows ADLs = 2356
#
# Total windows Fall = 216
#
# Total windows= 2572

# %%
from sklearn.model_selection import train_test_split

# Chia dữ liệu thành tập train và test
RateTrain = 0.6
random_state_=42
train_Standing, test_Standing = train_test_split(w_Standing, test_size=1 - RateTrain, random_state=random_state_)
train_Walking, test_Walking = train_test_split(w_Walking, test_size=1 - RateTrain, random_state=random_state_)
train_Jogging, test_Jogging = train_test_split(w_Jogging, test_size=1 - RateTrain, random_state=random_state_)
train_Jumping, test_Jumping  = train_test_split(w_Jumping , test_size=1 - RateTrain, random_state=random_state_)
train_StairsUp, test_StairsUp = train_test_split(w_StairsUp, test_size=1 - RateTrain, random_state=random_state_)
train_StairsDown, test_StairsDown = train_test_split(w_StairsDown, test_size=1 - RateTrain, random_state=random_state_)
train_ForwardLying, test_ForwardLying = train_test_split(w_ForwardLying, test_size=1 - RateTrain, random_state=random_state_)
train_FrontKneesLying, test_FrontKneesLying = train_test_split(w_FrontKneesLying, test_size=1 - RateTrain, random_state=random_state_)
train_SidewardLying, test_SidewardLying = train_test_split(w_SidewardLying, test_size=1 - RateTrain, random_state=random_state_)
train_Sitting, test_Sitting = train_test_split(w_Sitting, test_size=1 - RateTrain, random_state=random_state_)
# Tổng số mẫu trong từng tập
print('Train =', len(train_Standing) + len(train_Walking) + len(train_Jogging) + len(train_Jumping) + len(train_StairsUp) + len(train_StairsDown) +
      len(train_ForwardLying) + len(train_FrontKneesLying) + len(train_SidewardLying)+len(train_Sitting))

print('Test =', len(test_Standing) + len(test_Walking) + len(test_Jogging) + len(test_Jumping) + len(test_StairsUp) + len(test_StairsDown) +
      len(test_ForwardLying) + len(test_FrontKneesLying) + len(test_SidewardLying)+len(test_Sitting))

print('Total =', len(train_Standing) + len(train_Walking) + len(train_Jogging) + len(train_Jumping) + len(train_StairsUp) + len(train_StairsDown) +
      len(train_ForwardLying) + len(train_FrontKneesLying) + len(train_SidewardLying) +
      len(test_Standing) + len(test_Walking) + len(test_Jogging) + len(test_Jumping) + len(test_StairsUp) + len(test_StairsDown) +
      len(test_ForwardLying) + len(test_FrontKneesLying) + len(test_SidewardLying)+len(train_Sitting)+len(test_Sitting))
# Out:
# Train = 1539
# Test = 1033
# Total = 2572

# %%
acceleration_data = w_SidewardLying[10]
# Tạo trục X là số lượng mẫu (index)
sample_count = range(len(acceleration_data))

# Vẽ đồ thị gia tốc theo trục X (sample count) và các trục Y (X, Y, Z)
plt.figure(figsize=(10, 6))
plt.plot(sample_count, acceleration_data['Acc_X'], label='X', color='r')
plt.plot(sample_count, acceleration_data['Acc_Y'], label='Y', color='g')
plt.plot(sample_count, acceleration_data['Acc_Z'], label='Z', color='b')

plt.title('Accelerometer Data (ax, ay, az)')
plt.xlabel('Sample Count')
plt.ylabel('Acceleration (m/s²)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Tạo chuỗi dữ liệu và nhãn dùng để train
data_train = []
label_train = []

activity_labels = {
    "Standing": 0,
    "Walking": 1,
    "Jogging": 2,
    "Jumping": 3,
    "StairsUp": 4,
    "StairsDown": 5,
    "ForwardLying": 6,
    "FrontKneesLying": 6,
    "SidewardLying": 6,
    "Sitting": 7
}

# activity_labels = {
#     "Standing": 0,
#     "Walking": 0,
#     "Jogging": 0,
#     "Jumping": 0,
#     "StairsUp": 0,
#     "StairsDown": 0,
#     "ForwardLying": 1,
#     "FrontKneesLying": 1,
#     "SidewardLying": 1
# }

# Gán nhãn tương ứng với từng hoạt động
for acts in train_Standing:
    data_train.append(acts)
    label_train.append(activity_labels["Standing"])

for acts in train_Walking:
    data_train.append(acts)
    label_train.append(activity_labels["Walking"])

for acts in train_Jogging:
    data_train.append(acts)
    label_train.append(activity_labels["Jogging"])

for acts in train_Jumping:
    data_train.append(acts)
    label_train.append(activity_labels["Jumping"])

for acts in train_StairsUp:
    data_train.append(acts)
    label_train.append(activity_labels["StairsUp"])

for acts in train_StairsDown:
    data_train.append(acts)
    label_train.append(activity_labels["StairsDown"])

for acts in train_ForwardLying:
    data_train.append(acts)
    label_train.append(activity_labels["ForwardLying"])

for acts in train_FrontKneesLying:
    data_train.append(acts)
    label_train.append(activity_labels["FrontKneesLying"])

for acts in train_SidewardLying:
    data_train.append(acts)
    label_train.append(activity_labels["SidewardLying"])
    
for acts in train_Sitting:
    data_train.append(acts)
    label_train.append(activity_labels["Sitting"])

# Tạo chuỗi dữ liệu và nhãn dùng để test
data_test = []
label_test = []

for acts in test_Standing:
    data_test.append(acts)
    label_test.append(activity_labels["Standing"])

for acts in test_Walking:
    data_test.append(acts)
    label_test.append(activity_labels["Walking"])

for acts in test_Jogging:
    data_test.append(acts)
    label_test.append(activity_labels["Jogging"])

for acts in test_Jumping:
    data_test.append(acts)
    label_test.append(activity_labels["Jumping"])

for acts in test_StairsUp:
    data_test.append(acts)
    label_test.append(activity_labels["StairsUp"])

for acts in test_StairsDown:
    data_test.append(acts)
    label_test.append(activity_labels["StairsDown"])

for acts in test_ForwardLying:
    data_test.append(acts)
    label_test.append(activity_labels["ForwardLying"])

for acts in test_FrontKneesLying:
    data_test.append(acts)
    label_test.append(activity_labels["FrontKneesLying"])

for acts in test_SidewardLying:
    data_test.append(acts)
    label_test.append(activity_labels["SidewardLying"])
    
for acts in test_Sitting:
    data_test.append(acts)
    label_test.append(activity_labels["Sitting"])

# Kiểm tra độ dài của dữ liệu
print(f"Train data length: {len(data_train)}, Train labels length: {len(label_train)}")
print(f"Test data length: {len(data_test)}, Test labels length: {len(label_test)}")
# Out:
# Train data length: 1539, Train labels length: 1539
# Test data length: 1033, Test labels length: 1033

# %%
train_featuresNew = []
for action in data_train:
    feat = featuresFromBufferNew(action)
    train_featuresNew.append(feat)

test_featuresNew =[]
for action in data_test:
    feat = featuresFromBufferNew(action)
    test_featuresNew.append(feat)

# # Kiểm tra độ dài và nội dung dữ liệu đặc trưng
print(f"Train features shape: {np.array(train_featuresNew).shape}")
print(f"Test features shape: {np.array(test_featuresNew).shape}")
# Out:
# Train features shape: (1539, 48)
# Test features shape: (1033, 48)

# %%
max_score = 0
iteration = 0  # Đếm số lần lặp
target_score = 97.3  # Ngưỡng độ chính xác

print(f"Iteration Training model...")

#============
param_dist = {
    '_estimators': range(14, 30, 1),  # Số lượng cây từ 10 đến 20
    '_depth': range(12, 30,1),      # Độ sâu tối đa từ 10 đến 30
    '_random':range(1,100,1)       # ngau nhien 1:30
}

# Khởi tạo một DataFrame để lưu kết quả
results = []
_score = 0
# Thực hiện Grid Search thủ công
for _estimators in param_dist['_estimators']:
    for _depth in param_dist['_depth']:
        for _random in param_dist['_random']:
            # Huấn luyện mô hình với tham số hiện tại
            clf4 = RandomForestClassifier(criterion='entropy',n_jobs=-1, n_estimators=_estimators, max_depth=_depth,max_features='sqrt',class_weight='balanced', 
                                            bootstrap=True, random_state=_random).fit(train_featuresNew, label_train)
            
            # Dự đoán trên tập kiểm tra
            predicted_RF = clf4.predict(test_featuresNew)
            
            # Tính toán độ chính xác
            score = clf4.score(test_featuresNew, label_test)
            
            if _score < score:
                _score = score
                print("n_estimators=" , _estimators, "; max_depth= " , _depth, "; random_state= " , _random)
                print(f"Accuracy of RF classifier on test set: {round(score * 100, 1)}")
                def model_size_in_bytes(model):
                    return len(pickle.dumps(model))
                print(f"Model size (MB): {round(model_size_in_bytes(clf4)/1024**2, 3)}")

            # Lưu kết quả
            results.append({'n_estimators': _estimators, 'max_depth': _depth, 'random_state': _random, 'score': round(score * 100, 1)})
            del clf4
            if _score>= target_score:
                break 
            
results_df = pd.DataFrame(results)

# Tìm giá trị score cao nhất
max_score = results_df['score'].max()


# Lưu kết quả tốt nhất
high_score_df = results_df[results_df['score'] == max_score]
if len(high_score_df) > 0:
    best_params = high_score_df.iloc[0]
else:
    best_params = None


# results_df.to_csv(root_dir+"search_results_MobiFall3s.csv", index=False)

# %%
best_params
# Out:
# n_estimators    18.0
# max_depth       12.0
# random_state    54.0
# score           98.9
# Name: 7181, dtype: float64

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
# Huấn luyện mô hình Random Forest
from sklearn.ensemble import RandomForestClassifier
n_estimators_= int(best_params['n_estimators'])
max_depth_= int(best_params['max_depth'])
random_state_ = int(best_params['random_state'])
clf4 = RandomForestClassifier(criterion='entropy',n_jobs=-1, n_estimators=n_estimators_,
                                max_depth=max_depth_,max_features='sqrt',class_weight='balanced', 
                                bootstrap=True, random_state=56).fit(train_featuresNew, label_train)
predicted4 = clf4.predict(test_featuresNew)
confusion_test4 = confusion_matrix(label_test, predicted4)


# Dự đoán trên tập test
predicted_RF = clf4.predict(test_featuresNew)

# Đánh giá mô hình
train_accuracy = clf4.score(train_featuresNew, label_train)*100
test_accuracy = clf4.score(test_featuresNew, label_test)*100

print(f"Accuracy of RF classifier on training set: {train_accuracy:.1f}")
print(f"Accuracy of RF classifier on test set: {test_accuracy:.1f}")
# # Cập nhật các nhãn với tên thật của các hành động
target_names = [
    'ST', # 0
    'WA', # 1
    'JO', # 2
    'JU', # 3
    'US', # 4
    'DS', # 5
    'FA', # 6
    'SI'#7
]

# # Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(5, 6))
sns.heatmap(confusion_test4, annot=True, fmt="d", cmap="Greens", xticklabels=target_names, yticklabels=target_names, cbar=False, annot_kws={"size": 17})

# Set labels and title with font size 14
plt.xlabel('Predicted', fontsize=17)
plt.ylabel('True', fontsize=17)
plt.title('(b)  Results on MobiFall', fontsize=17)
# Rotate x-axis labels by 20 degrees
plt.xticks(rotation=90,fontsize=17)
plt.yticks(rotation=0,fontsize=17)
# Show plot
plt.show()



# Hàm tính AUC cho bài toán đa lớp
def calculate_auc_multiclass(model, test_feature, label_test):
    try:
        # Predict xác suất (nếu model hỗ trợ)
        predicted_probs = model.predict_proba(test_feature)
        return roc_auc_score(label_test, predicted_probs, multi_class='ovr') * 100  # Tính AUC (%)
    except AttributeError:  # Nếu model không hỗ trợ predict_proba
        return None
start_time = time.time()
clf4.fit(train_featuresNew, label_train)
train_time = time.time() - start_time

# Dự đoán
start_time = time.time()
predicted = clf4.predict(test_featuresNew)
test_time = time.time() - start_time

# Confusion matrix
confusion_test = confusion_matrix(label_test, predicted)

# Tính toán các chỉ số từ ma trận nhầm lẫn
avg_accuracy, avg_sensitivity, avg_specificity, avg_precision, _ = calculate_metrics(confusion_test,target_names)

# AUC (cho đa lớp)
auc_score = calculate_auc_multiclass(clf4, test_featuresNew, label_test)

# Tính Accuracy trên tập kiểm tra
test_accuracy = clf4.score(test_featuresNew, label_test)* 100  # Accuracy (%)

# Tính F1-score (macro và micro) trên tập kiểm tra
test_f1_macro = f1_score(label_test, predicted, average='macro') * 100  # F1 macro (%)
test_f1_micro = f1_score(label_test, predicted, average='micro') * 100  # F1 micro (%)
results = []
# Lưu kết quả
results.append({
        'Model':'RF',
        'Train Time (seconds)': train_time,
        'Test Time (seconds)': test_time,
        'Model Size (MB)': round(model_size_in_bytes(clf4)/1024**2,3),
        'Accuracy (%)': round(avg_accuracy * 100, 1),  # Accuracy (%)
        'Sensitivity (%)': round(avg_sensitivity * 100, 1),  # Sensitivity (%)
        'Specificity (%)': round(avg_specificity * 100, 1),  # Specificity (%)
        'Precision (%)': round(avg_precision * 100, 1),  # Precision (%)
        'Test Accuracy (%)': round(test_accuracy, 1),  # Test Accuracy (%)
        'Test F1 Macro (%)': round(test_f1_macro, 1),
        'Test F1 Micro (%)': round(test_f1_micro, 1),
        'AUC (%)': round(auc_score, 1)  # Làm tròn AUC
    })
# Chuyển kết quả thành DataFrame để tiện xử lý
results_model = pd.DataFrame(results).copy()

# Hiển thị kết quả
results_model
# Out:
# Accuracy of RF classifier on training set: 100.0
# Accuracy of RF classifier on test set: 98.0
#   Model  Train Time (seconds)  Test Time (seconds)  Model Size (MB)  \
# 0    RF               0.05476             0.011946             0.28
#
#    Accuracy (%)  Sensitivity (%)  Specificity (%)  Precision (%)  \
# 0          99.5             95.1             99.7           96.8
#
#    Test Accuracy (%)  Test F1 Macro (%)  Test F1 Micro (%)  AUC (%)
# 0               98.0               95.8               98.0     99.7

# %%
# Initialize metrics
metrics = []
confusion_matrix_df = pd.DataFrame(confusion_test, index=target_names, columns=target_names)
# Convert DataFrame to numpy array for easier calculations
confusion_= confusion_matrix_df.values
n_classes = len(confusion_)
metrics = []
# Tái tạo y_true và y_pred từ ma trận nhầm lẫn
from sklearn.metrics import precision_score, recall_score, f1_score
y_true_all = []
y_pred_all = []
for i in range(n_classes):
    for j in range(n_classes):
        count = confusion_[i, j]
        y_true_all += [i] * count
        y_pred_all += [j] * count

# Tính metrics cho từng lớp
metrics = []
for i in range(n_classes):
    TP = confusion_[i, i]
    FP = np.sum(confusion_[:, i]) - TP
    FN = np.sum(confusion_[i, :]) - TP
    TN = np.sum(confusion_) - (TP + FP + FN)

    accuracy = (TP + TN) / np.sum(confusion_)
    sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
    specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    f1 = (2 * precision * sensitivity) / (precision + sensitivity) if (precision + sensitivity) > 0 else 0

    metrics.append({
        'Activity': confusion_matrix_df.index[i],
        'Acc': round(accuracy * 100, 1),
        'Sen': round(sensitivity * 100, 1),
        'Spe': round(specificity * 100, 1),
        'Pre': round(precision * 100, 1),
        'F1': round(f1 * 100, 1)
    })

# Tính metrics tổng thể
overall_accuracy = np.trace(confusion_) / np.sum(confusion_)
overall_precision = precision_score(y_true_all, y_pred_all, average='macro', zero_division=0)
overall_sensitivity = recall_score(y_true_all, y_pred_all, average='macro', zero_division=0)
overall_f1_micro = f1_score(y_true_all, y_pred_all, average='micro', zero_division=0)

# Tính specificity tổng thể thủ công
overall_specificity_list = []
for i in range(n_classes):
    TP = confusion_[i, i]
    FP = np.sum(confusion_[:, i]) - TP
    TN = np.sum(confusion_) - (np.sum(confusion_[i, :]) + FP)
    specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
    overall_specificity_list.append(specificity)
overall_specificity = np.mean(overall_specificity_list)

# Tổng hợp kết quả
metrics_df = pd.DataFrame(metrics)
overall_metrics = pd.DataFrame([{
    'Activity': 'Overall',
    'Acc': round(overall_accuracy * 100, 1),
    'Sen': round(overall_sensitivity * 100, 1),
    'Spe': round(overall_specificity * 100, 1),
    'Pre': round(overall_precision * 100, 1),
    'F1': round(overall_f1_micro * 100, 1)  # Gán F1micro vào cột F1
}])

# Combine into one DataFrame
full_metrics_df = pd.concat([metrics_df, overall_metrics], ignore_index=True)
full_metrics_df
# Out:
#   Activity    Acc    Sen    Spe    Pre     F1
# 0       ST   99.9  100.0   99.9   99.7   99.8
# 1       WA   99.1   99.7   98.9   97.6   98.6
# 2       JO   99.6  100.0   99.6   95.7   97.8
# 3       JU   99.6   95.5  100.0  100.0   97.7
# 4       US   98.9   88.9   99.4   87.0   87.9
# 5       DS   98.7   76.6   99.8   94.7   84.7
# 6       FA  100.0  100.0  100.0  100.0  100.0
# 7       SI  100.0  100.0  100.0  100.0  100.0
# 8  Overall   98.0   95.1   99.7   96.8   98.0

# %% [markdown]
# Xác thực chéo ngẫu nhiên 5 lần

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import f1_score
X_full = np.array(list(train_featuresNew)+list(test_featuresNew))
y_full = np.array(label_train+label_test)

kf_cv = KFold(n_splits=5, shuffle=True, random_state=1)

cv_train_accuracies = []
cv_test_accuracies = []
cv_conf_matrices = []

# Để lưu fold tốt nhất
best_fold_index = -1
best_test_acc = -1
best_conf_matrix = None
best_train_acc = -1
train_feature_= []
test_feature_=[]
label_train_=[]
label_test_=[]
mode_rf = 0
resultsKfold=[]
for fold_index, (cv_train_idx, cv_test_idx) in enumerate(kf_cv.split(X_full), start=1):
    X_cv_train = X_full[cv_train_idx]
    y_cv_train = y_full[cv_train_idx]
    X_cv_test = X_full[cv_test_idx]
    y_cv_test = y_full[cv_test_idx]
    rf_cv_model = RandomForestClassifier(criterion='entropy',n_jobs=-1, n_estimators=n_estimators_,
                                max_depth=max_depth_,max_features='sqrt',class_weight='balanced', 
                                bootstrap=True, random_state=random_state_).fit(X_cv_train, y_cv_train)

    y_cv_pred = rf_cv_model.predict(X_cv_test)

    acc_cv_train = rf_cv_model.score(X_cv_train, y_cv_train)
    acc_cv_test = rf_cv_model.score(X_cv_test,y_cv_test)
    cm_cv = confusion_matrix(y_cv_test, y_cv_pred)
     # Tính toán các chỉ số từ ma trận nhầm lẫn
    avg_accuracy, avg_sensitivity, avg_specificity, avg_precision, _ = calculate_metrics(cm_cv,target_names)

    # AUC (cho đa lớp)
    auc_score = calculate_auc_multiclass(rf_cv_model, X_cv_test, y_cv_test)

    # Tính Accuracy trên tập kiểm tra
    test_accuracy = accuracy_score(y_cv_test, y_cv_pred) * 100  # Accuracy (%)

    # Tính F1-score (macro và micro) trên tập kiểm tra
    test_f1_macro = f1_score(y_cv_test, y_cv_pred, average='macro') * 100  # F1 macro (%)
    test_f1_micro = f1_score(y_cv_test, y_cv_pred, average='micro') * 100  # F1 micro (%)

    # Lưu kết quả
    resultsKfold.append({
        'Fold': fold_index,
        'Model Size (Bytes)': model_size_in_bytes(rf_cv_model),
        'Accuracy (%)': round(avg_accuracy * 100, 1),  # Accuracy (%)
        'Sensitivity (%)': round(avg_sensitivity * 100, 1),  # Sensitivity (%)
        'Specificity (%)': round(avg_specificity * 100, 1),  # Specificity (%)
        'Precision (%)': round(avg_precision * 100, 1),  # Precision (%)
        'Train F1 Micro':round(acc_cv_train*100,1),
        'Test F1 Micro (%)': round(test_f1_micro, 1),
        'Test F1 Macro (%)': round(test_f1_macro, 1),
        'AUC': round(auc_score*100, 1)  # Làm tròn AUC
    })

    # Lưu lại fold tốt nhất nếu tốt hơn fold trước đó
    if acc_cv_test > best_test_acc:
        best_fold_index = fold_index
        best_test_acc = acc_cv_test
        best_train_acc = acc_cv_train
        best_conf_matrix = cm_cv
        train_feature_= X_cv_train
        test_feature_=X_cv_test
        label_train_=y_cv_train
        label_test_=y_cv_test
        mode_rf = rf_cv_model
    # Lưu để thống kê chung
    cv_train_accuracies.append(acc_cv_train)
    cv_test_accuracies.append(acc_cv_test)
    cv_conf_matrices.append(cm_cv)

df_resultsKfold = pd.DataFrame(resultsKfold)
# Tính trung bình các cột số học, bỏ qua cột 'Model'
mean_row = df_resultsKfold.drop(columns=['Fold']).mean(numeric_only=True)
mean_row = mean_row.round(1)
# Chuyển thành dict và thêm cột 'Model' là 'Average'
mean_row_dict = {'Fold': 'Average'}
mean_row_dict.update(mean_row.to_dict())

# Thêm vào cuối danh sách kết quả
resultsKfold.append(mean_row_dict)
df_resultsKfold = pd.DataFrame(resultsKfold)
df_resultsKfold
# Out:
#       Fold  Model Size (Bytes)  Accuracy (%)  Sensitivity (%)  \
# 0        1            329566.0          99.6             95.9
# 1        2            339294.0          99.4             94.4
# 2        3            339294.0          99.2             91.0
# 3        4            352094.0          99.4             94.1
# 4        5            348007.0          99.4             94.7
# 5  Average            341651.0          99.4             94.0
#
#    Specificity (%)  Precision (%)  Train F1 Micro  Test F1 Micro (%)  \
# 0             99.7           98.5            99.9               98.3
# 1             99.6           96.0           100.0               97.5
# 2             99.5           95.9           100.0               96.9
# 3             99.7           95.0           100.0               97.7
# 4             99.6           95.6           100.0               97.7
# 5             99.6           96.2           100.0               97.6
#
#    Test F1 Macro (%)    AUC
# ...

# %%
import time
import pickle
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, f1_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
import xgboost as xgb
import lightgbm as lgb
import warnings
warnings.filterwarnings("ignore")

def model_size_in_bytes(model):
    return len(pickle.dumps(model))

def calculate_auc_multiclass(model, test_features, label_test):
    try:
        predicted_probs = model.predict_proba(test_features)
        return roc_auc_score(label_test, predicted_probs, multi_class='ovr')
    except:
        return None

# Gán lại để dễ dùng
data_full = np.array(list(train_featuresNew) + list(test_featuresNew))
label_full = np.array(label_train + label_test)

# KFold
kf_cv = KFold(n_splits=5, shuffle=True, random_state=1)

# Các mô hình (không thay đổi tham số)
models = [
    ('RF', RandomForestClassifier(criterion='entropy',n_jobs=-1, n_estimators=n_estimators_,
                                max_depth=max_depth_,max_features='sqrt',class_weight='balanced', 
                                bootstrap=True, random_state=random_state_)),
    ('XGBoost', xgb.XGBClassifier(n_estimators=18, max_depth=12, learning_rate=0.05, random_state=random_state_)),
    ('DT', DecisionTreeClassifier(max_depth=18)),
    ('GBDT', GradientBoostingClassifier(learning_rate=0.05, n_estimators=18, max_depth=12, random_state=random_state_)),
    ('SVM', SVC(C=27, kernel='linear', random_state=random_state_, probability=True)),
    ('LightGBM', lgb.LGBMClassifier(n_estimators=18, max_depth=12, learning_rate=0.05, random_state=random_state_, verbose=-1))
]

final_results = []
total_model = {}
for model_name, model_ in models:
    nameModel,size_model,acc_list, sens_list, spec_list, prec_list = [],[], [], [], [],[]
    train_f1_micro_list, test_f1_micro_list, test_f1_macro_list, auc_list = [], [], [], []
    
    for train_index, test_index in kf_cv.split(data_full):
        fold_train, fold_test = data_full[train_index], data_full[test_index]
        label_fold_train, label_fold_test = label_full[train_index], label_full[test_index]
        
        model_.fit(fold_train, label_fold_train)
        y_pred = model_.predict(fold_test)
        
        cm = confusion_matrix(label_fold_test, y_pred)
        avg_accuracy, avg_sensitivity, avg_specificity, avg_precision, _ = calculate_metrics(cm, target_names)

        # F1 and AUC
        nameModel.append(model_name)
        size_model.append(model_size_in_bytes(model_))
        f1_micro_train = round(f1_score(label_fold_train, model_.predict(fold_train), average='micro') * 100, 1)
        f1_micro_test = round(f1_score(label_fold_test, y_pred, average='micro') * 100, 1)
        f1_macro_test = round(f1_score(label_fold_test, y_pred, average='macro') * 100, 1)
        avg_accuracy = round(avg_accuracy * 100, 1)
        avg_sensitivity = round(avg_sensitivity * 100, 1)
        avg_specificity = round(avg_specificity * 100, 1)
        avg_precision = round(avg_precision * 100, 1)
        auc_score = calculate_auc_multiclass(model_, fold_test, label_fold_test)
        auc_score = round(auc_score*100, 1) if auc_score is not None else None
        acc_list.append(avg_accuracy)
        sens_list.append(avg_sensitivity)
        spec_list.append(avg_specificity)
        prec_list.append(avg_precision)
        train_f1_micro_list.append(f1_micro_train)
        test_f1_micro_list.append(f1_micro_test)
        test_f1_macro_list.append(f1_macro_test)
        auc_list.append(auc_score)
    # Sau khi tính xong các metrics từng fold
    final_results.append({
        'Model': model_name,
        'Model Size (Bytes)': round(np.mean(size_model), 1),
        'Accuracy (%)': round(np.mean(acc_list), 1),
        'Sensitivity (%)': round(np.mean(sens_list), 1),
        'Specificity (%)': round(np.mean(spec_list), 1),
        'Precision (%)': round(np.mean(prec_list), 1),
        'Train F1 Micro (%)': round(np.mean(train_f1_micro_list), 1),
        'Test F1 Micro (%)': round(np.mean(test_f1_micro_list), 1),
        'Test F1 Macro (%)': round(np.mean(test_f1_macro_list), 1),
        'AUC (%)': round(np.mean(auc_list), 1)
    })
    total_model[model_name] = {
        'Model': nameModel.copy(),
        'Model Size (Bytes)': size_model.copy(),
        'Accuracy (%)': acc_list.copy(),
        'Sensitivity (%)': sens_list.copy(),
        'Specificity (%)': spec_list.copy(),
        'Precision (%)': prec_list.copy(),
        'Train F1 Micro (%)': train_f1_micro_list.copy(),
        'Test F1 Micro (%)': test_f1_micro_list.copy(),
        'Test F1 Macro (%)': test_f1_macro_list.copy(),
        'AUC (%)': [auc if auc is not None else None for auc in auc_list.copy()]  # scale AUC cho đồng bộ %
    }

# Xuất kết quả
results_model = pd.DataFrame(final_results)
results_model
# Out:
#       Model  Model Size (Bytes)  Accuracy (%)  Sensitivity (%)  \
# 0        RF            341651.0          99.4             94.0
# 1   XGBoost            215597.0          99.3             93.6
# 2        DT             17415.0          98.7             89.0
# 3      GBDT           2659119.0          98.6             86.9
# 4       SVM             71452.2          99.4             94.6
# 5  LightGBM            492229.8          99.2             91.7
#
#    Specificity (%)  Precision (%)  Train F1 Micro (%)  Test F1 Micro (%)  \
# 0             99.6           96.2               100.0               97.6
# 1             99.6           95.4                99.6               97.4
# 2             99.2           89.3               100.0               94.8
# 3             99.1           94.1               100.0               94.5
# 4             99.7           95.8                99.8               97.8
# 5             99.5           96.2                99.5               96.8
#
# ...

# %%
total_model['RF']['Train F1 Micro (%)']
# Out:
# [99.9, 100.0, 100.0, 100.0, 100.0]

# %%
total_model['RF']['Test F1 Micro (%)']
# Out:
# [98.3, 97.5, 96.9, 97.7, 97.7]

# %%
root_dirMobifall = root_dir+ '/backup result mobifall/'
# try:
# # Ghi kết quả vào file CSV
#     joblib.dump(data_train, root_dirMobifall+'data_train.pkl')
#     joblib.dump(data_test, root_dirMobifall+'data_test.pkl')
#     joblib.dump(train_featuresNew, root_dirMobifall+'MobiFall_train_features.pkl')
#     joblib.dump(test_featuresNew, root_dirMobifall+'MobiFall_test_features.pkl')
#     joblib.dump(label_test, root_dirMobifall+'MobiFall_label_test.pkl')
#     joblib.dump(label_train, root_dirMobifall+'MobiFall_label_train.pkl')
#     joblib.dump(clf4, root_dirMobifall+'clf4.pkl')
#     joblib.dump(best_params, root_dirMobifall+'best_params.pkl')
#     joblib.dump(total_model, root_dirMobifall+'total_model.pkl')
#     results_df.to_csv(root_dirMobifall+"results_model.csv", index=False)
#     print("Kết quả đã được ghi thành công vào file CSV.")
# except Exception as e:
#     print(f"Không thể ghi file CSV. Lỗi: {e}")

try:
    # Load các file dữ liệu và mô hình
    data_train = joblib.load(os.path.join(root_dirMobifall, 'data_train.pkl'))
    data_test = joblib.load(os.path.join(root_dirMobifall, 'data_test.pkl'))
    train_featuresNew = joblib.load(os.path.join(root_dirMobifall, 'MobiFall_train_features.pkl'))
    test_featuresNew = joblib.load(os.path.join(root_dirMobifall, 'MobiFall_test_features.pkl'))
    label_train = joblib.load(os.path.join(root_dirMobifall, 'MobiFall_label_train.pkl'))
    label_test = joblib.load(os.path.join(root_dirMobifall, 'MobiFall_label_test.pkl'))
    clf4 = joblib.load(os.path.join(root_dirMobifall, 'clf4.pkl'))
    best_params = joblib.load(os.path.join(root_dirMobifall, 'best_params.pkl'))
    total_model = joblib.load(os.path.join(root_dirMobifall, 'total_model.pkl'))
    results_df = pd.read_csv(os.path.join(root_dirMobifall, 'results_model.csv'))

    print("Tải dữ liệu thành công.")
except Exception as e:
    print(f"Không thể tải dữ liệu. Lỗi: {e}")
# Out:
# Tải dữ liệu thành công.

# %%
root_dirMobifall = root_dir+ '/backup result mobifall/'
# try:
# # Ghi kết quả vào file CSV
#     joblib.dump(data_train, root_dirMobifall+'data_train.pkl')
#     joblib.dump(data_test, root_dirMobifall+'data_test.pkl')
#     joblib.dump(train_featuresNew, root_dirMobifall+'MobiFall_train_features.pkl')
#     joblib.dump(test_featuresNew, root_dirMobifall+'MobiFall_test_features.pkl')
#     joblib.dump(label_test, root_dirMobifall+'MobiFall_label_test.pkl')
#     joblib.dump(label_train, root_dirMobifall+'MobiFall_label_train.pkl')
#     joblib.dump(clf4, root_dirMobifall+'clf4.pkl')
#     joblib.dump(best_params, root_dirMobifall+'best_params.pkl')
#     joblib.dump(total_model, root_dirMobifall+'total_model.pkl')
#     results_df.to_csv(root_dirMobifall+"results_model.csv", index=False)
#     print("Kết quả đã được ghi thành công vào file CSV.")
# except Exception as e:
#     print(f"Không thể ghi file CSV. Lỗi: {e}")

try:
    # Load các file dữ liệu và mô hình
    data_train = joblib.load(os.path.join(root_dirMobifall, 'data_train.pkl'))
    data_test = joblib.load(os.path.join(root_dirMobifall, 'data_test.pkl'))
    train_featuresNew = joblib.load(os.path.join(root_dirMobifall, 'MobiFall_train_features.pkl'))
    test_featuresNew = joblib.load(os.path.join(root_dirMobifall, 'MobiFall_test_features.pkl'))
    label_train = joblib.load(os.path.join(root_dirMobifall, 'MobiFall_label_train.pkl'))
    label_test = joblib.load(os.path.join(root_dirMobifall, 'MobiFall_label_test.pkl'))
    clf4 = joblib.load(os.path.join(root_dirMobifall, 'clf4.pkl'))
    best_params = joblib.load(os.path.join(root_dirMobifall, 'best_params.pkl'))
    total_model = joblib.load(os.path.join(root_dirMobifall, 'total_model.pkl'))
    results_df = pd.read_csv(os.path.join(root_dirMobifall, 'results_model.csv'))

    print("Tải dữ liệu thành công.")
except Exception as e:
    print(f"Không thể tải dữ liệu. Lỗi: {e}")
# Out:
# Không thể tải dữ liệu. Lỗi: name 'joblib' is not defined
